# %%
#Imports
import io
import os
import gc
import copy
import math
import ctypes
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_fscore_support, accuracy_score, balanced_accuracy_score, matthews_corrcoef
from sklearn import metrics

import tensorflow as tf
from tensorflow.keras import Input, Model, layers, losses, optimizers, callbacks
import tensorflow_decision_forests as tfdf

#Notebook settings
default_max_columns = None
default_max_rows = 10
pd.set_option('display.max_columns', default_max_columns)
pd.set_option('display.max_rows', default_max_rows)

model_name = "RANDOM_FOREST"
label_column = "Label"
batch_size = 512
num_datasets = 6
cwd = os.getcwd()
# Out:
# 2025-02-05 12:15:27.757477: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-05 12:15:27.830280: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-05 12:15:27.889118: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-05 12:15:27.947413: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-05 12:15:27.964095: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-05 12:15:28.063169: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-05 12:15:29.159819: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#Utility functions
def split_xy(df, colname):
    y_cols = [c for c in df.columns if c.startswith(colname)]
    x_cols = np.setdiff1d(df.columns, y_cols)
    X = df[x_cols]
    Y = df[y_cols]
    return X, Y

# %%
# %%time
#Training and evaluating loop designed to work with memory constraints 

df_names = ['NF-UNSW-NB15', 'NF-CSE-CIC-IDS2018', 'NF-BoT-IoT', 'NF-ToN-IoT', 'X-IIoTiD', 'WUSTL-IIOT']
result_df = pd.DataFrame(columns=("TRAIN_DATASET", "EVAL_DATASET", "METRIC", "VAlUE", "LABEL", "MODEL"))

for i in range(num_datasets):

    #Model definiton
    #Random Forrest Classifier with 50 Trees, max depth of 4
    random_forest_model = tfdf.keras.RandomForestModel(
        task=tfdf.keras.Task.CLASSIFICATION,
        missing_value_policy = "GLOBAL_IMPUTATION",
        num_trees = 50,
        max_depth = 10,
        #growing_strategy="BEST_FIRST_GLOBAL",
        #max_num_nodes = 5,
        verbose = 0,
        #compute_oob_variable_importances=True, #Uses too much RAM
        sorting_strategy="IN_NODE",
    )

    #Load training and validation data
    print("Loading "+df_names[i]+" trainingset")
    df_train = pd.read_csv(cwd+"/datasets/"+df_names[i]+"_Trainset.csv", dtype=float)
    print(df_train.shape)
    df_val = pd.read_csv(cwd+"/datasets/"+df_names[i]+"_Valset.csv", dtype=float)
    trainset = tfdf.keras.pd_dataframe_to_tf_dataset(df_train, label=label_column, batch_size = batch_size)
    del df_train
    valset = tfdf.keras.pd_dataframe_to_tf_dataset(df_val, label=label_column, batch_size = batch_size)
    del df_val
    gc.collect()
    print("Loading complete")
    
    #Train
    print("Training on "+df_names[i]+" trainingset")
    random_forest_model.fit(trainset,validation_data = valset)
    del trainset, valset
    gc.collect
    print("Training complete")
    
    #Evaluation
    for j in range(num_datasets):

        print("Loading "+df_names[j]+" testset")
        #Load test data
        df_test = pd.read_csv(cwd+"/datasets/"+df_names[j]+"_Testset.csv", dtype=float)
        print(df_test.shape)
        testset = tfdf.keras.pd_dataframe_to_tf_dataset(df_test, label=label_column, batch_size = batch_size)
        xtest, ytest = split_xy(df_test, label_column)
        del df_test,xtest
        print("Loading complete")

        #Predict
        print("Evaluating model trained on "+df_names[i]+" trainset on "+df_names[j]+" testset")
        ypred = ((random_forest_model.predict(testset) > 0.5).astype("int32"))
        del testset
        print("Evaluation complete")

        #Results
        print("Results for:...")
        print("Model trained on "+df_names[i]+" and evaluated on "+df_names[j])
        print(confusion_matrix(ytest, ypred))
        print(classification_report(ytest, ypred))
        precision, recall, f1_score, support = precision_recall_fscore_support(ytest,ypred, zero_division = 0.0)
        accuracy = accuracy_score(ytest, ypred)
        balanced_accuracy = balanced_accuracy_score(ytest, ypred)
        mcc = matthews_corrcoef(ytest, ypred)
        print("---")

        del ypred,ytest
        gc.collect

        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"ACCURACY", "VAlUE":accuracy, "LABEL":"BOTH", "MODEL":model_name}, index = [0])], ignore_index=True)
        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"BALANCED_ACCURACY", "VAlUE":balanced_accuracy, "LABEL":"BOTH", "MODEL":model_name}, index = [0])], ignore_index=True)
        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"MCC", "VAlUE":mcc, "LABEL":"BOTH", "MODEL":model_name}, index = [0])], ignore_index=True)
        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"PRECISION", "VAlUE":precision[0], "LABEL":"0", "MODEL":model_name}, index = [0])], ignore_index=True)
        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"PRECISION", "VAlUE":precision[1], "LABEL":"1", "MODEL":model_name}, index = [0])], ignore_index=True)   
        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"RECALL", "VAlUE":recall[0], "LABEL":"0", "MODEL":model_name}, index = [0])], ignore_index=True)
        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"RECALL", "VAlUE":recall[1], "LABEL":"1", "MODEL":model_name}, index = [0])], ignore_index=True)
        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"F1_SCORE", "VAlUE":f1_score[0], "LABEL":"0", "MODEL":model_name}, index = [0])], ignore_index=True)
        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"F1_SCORE", "VAlUE":f1_score[1], "LABEL":"1", "MODEL":model_name}, index = [0])], ignore_index=True)
        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"SUPPORT", "VAlUE":support[0], "LABEL":"0", "MODEL":model_name}, index = [0])], ignore_index=True)
        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"SUPPORT", "VAlUE":support[1], "LABEL":"1", "MODEL":model_name}, index = [0])], ignore_index=True)
        
    del random_forest_model
    gc.collect
    libc = ctypes.CDLL("libc.so.6") # clearing cache 
    libc.malloc_trim(0)

    print("Cleanup complete")
    print("---+++---")
# Out:
# Loading NF-UNSW-NB15 trainingset
# (1298494, 33)
# Loading complete
# Training on NF-UNSW-NB15 trainingset
# Num validation examples: tf.Tensor(162312, shape=(), dtype=int32)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738754156.287662    5704 kernel.cc:774] Start Yggdrasil model training
# I0000 00:00:1738754156.297354    5704 kernel.cc:775] Collect training examples
# I0000 00:00:1738754156.297407    5704 kernel.cc:787] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: false
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1738754156.298467    5704 kernel.cc:394] Number of batches: 2537
# I0000 00:00:1738754156.298491    5704 kernel.cc:395] Number of examples: 1298494
# I0000 00:00:1738754156.568764    5704 kernel.cc:794] Training dataset:
# Number of records: 1298494
# Number of columns: 33
#
# Number of columns by type:
# 	NUMERICAL: 32 (96.9697%)
# 	CATEGORICAL: 1 (3.0303%)
#
# Columns:
#
# NUMERICAL: 32 (96.9697%)
# 	0: "FLOW_DURATION_MILLISECONDS" NUMERICAL mean:54977 min:0 max:4.29495e+06 sd:480396
# 	1: "IN_BYTES" NUMERICAL mean:5337.76 min:52 max:2.68543e+07 sd:79198.2
# 	2: "IN_PKTS" NUMERICAL mean:39.5069 min:1 max:20038 sd:89.1454
# 	3: "IPV4_DST_ADDR_octet0" NUMERICAL mean:148.899 min:10 max:224 sd:4.43289
# 	4: "IPV4_DST_ADDR_octet1" NUMERICAL mean:170.82 min:0 max:171 sd:5.1308
# 	5: "IPV4_DST_ADDR_octet2" NUMERICAL mean:125.79 min:0 max:241 sd:6.06976
# 	6: "IPV4_DST_ADDR_octet3" NUMERICAL mean:5.16326 min:0 max:255 sd:4.25521
# 	7: "IPV4_SRC_ADDR_octet0" NUMERICAL mean:67.1074 min:10 max:192 sd:29.6313
# 	8: "IPV4_SRC_ADDR_octet1" NUMERICAL mean:157.562 min:0 max:171 sd:30.8476
# 	9: "IPV4_SRC_ADDR_octet2" NUMERICAL mean:12.4631 min:0 max:241 sd:44.9696
# 	10: "IPV4_SRC_ADDR_octet3" NUMERICAL mean:4.25516 min:0 max:243 sd:3.01547
# 	11: "L4_DST_PORT" NUMERICAL mean:13828.1 min:0 max:65535 sd:19597.5
# 	12: "L4_SRC_PORT" NUMERICAL mean:32639.7 min:0 max:65535 sd:19193.8
# 	13: "OUT_BYTES" NUMERICAL mean:42630.3 min:0 max:1.46568e+07 sd:174766
# 	14: "OUT_PKTS" NUMERICAL mean:50.7128 min:0 max:11024 sd:131.027
# 	15: "PROTOCOL_ARP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	16: "PROTOCOL_DCCP" NUMERICAL mean:4.62074e-05 min:0 max:1 sd:0.00679744
# 	17: "PROTOCOL_GRE" NUMERICAL mean:5.23684e-05 min:0 max:1 sd:0.00723641
# 	18: "PROTOCOL_HOPOPT" NUMERICAL mean:2.46439e-05 min:0 max:1 sd:0.0049642
# 	19: "PROTOCOL_ICMP" NUMERICAL mean:0.000435119 min:0 max:1 sd:0.020855
# 	20: "PROTOCOL_IGMP" NUMERICAL mean:7.31617e-05 min:0 max:1 sd:0.00855315
# 	21: "PROTOCOL_IPv6" NUMERICAL mean:4.3897e-05 min:0 max:1 sd:0.00662534
# 	22: "PROTOCOL_IPv6-ICMP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	23: "PROTOCOL_OSPFIGP" NUMERICAL mean:0.00109588 min:0 max:1 sd:0.033086
# 	24: "PROTOCOL_OTHER" NUMERICAL mean:0.00612094 min:0 max:1 sd:0.0779966
# 	25: "PROTOCOL_PIM" NUMERICAL mean:5.08281e-05 min:0 max:1 sd:0.0071292
# 	26: "PROTOCOL_SCTP" NUMERICAL mean:4.3897e-05 min:0 max:1 sd:0.00662534
# 	27: "PROTOCOL_SUN-ND" NUMERICAL mean:4.54373e-05 min:0 max:1 sd:0.00674056
# 	28: "PROTOCOL_SWIPE" NUMERICAL mean:4.77476e-05 min:0 max:1 sd:0.0069098
# 	29: "PROTOCOL_TCP" NUMERICAL mean:0.718371 min:0 max:1 sd:0.449794
# 	30: "PROTOCOL_TLSP" NUMERICAL mean:4.69775e-05 min:0 max:1 sd:0.00685385
# 	31: "PROTOCOL_UDP" NUMERICAL mean:0.273502 min:0 max:1 sd:0.445756
#
# CATEGORICAL: 1 (3.0303%)
# 	32: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1738754156.568886    5704 kernel.cc:799] Collect validation dataset
# I0000 00:00:1738754156.568975    5704 kernel.cc:394] Number of batches: 318
# I0000 00:00:1738754156.568982    5704 kernel.cc:395] Number of examples: 162312
# I0000 00:00:1738754156.598367    5704 kernel.cc:805] Validation dataset:
# Number of records: 162312
# Number of columns: 33
#
# Number of columns by type:
# 	NUMERICAL: 32 (96.9697%)
# 	CATEGORICAL: 1 (3.0303%)
#
# Columns:
#
# NUMERICAL: 32 (96.9697%)
# 	0: "FLOW_DURATION_MILLISECONDS" NUMERICAL mean:54959.6 min:0 max:4.29495e+06 sd:480363
# 	1: "IN_BYTES" NUMERICAL mean:5293.47 min:52 max:9.18537e+06 sd:60607.4
# 	2: "IN_PKTS" NUMERICAL mean:39.4342 min:1 max:6988 sd:80.3112
# 	3: "IPV4_DST_ADDR_octet0" NUMERICAL mean:148.891 min:10 max:224 sd:4.56955
# 	4: "IPV4_DST_ADDR_octet1" NUMERICAL mean:170.811 min:0 max:171 sd:5.2455
# 	5: "IPV4_DST_ADDR_octet2" NUMERICAL mean:125.777 min:0 max:241 sd:6.23932
# 	6: "IPV4_DST_ADDR_octet3" NUMERICAL mean:5.15985 min:0 max:255 sd:4.33063
# 	7: "IPV4_SRC_ADDR_octet0" NUMERICAL mean:67.1221 min:10 max:192 sd:29.663
# 	8: "IPV4_SRC_ADDR_octet1" NUMERICAL mean:157.54 min:40 max:171 sd:30.8853
# 	9: "IPV4_SRC_ADDR_octet2" NUMERICAL mean:12.5015 min:0 max:241 sd:45.0255
# 	10: "IPV4_SRC_ADDR_octet3" NUMERICAL mean:4.25317 min:0 max:243 sd:2.95086
# 	11: "L4_DST_PORT" NUMERICAL mean:13880.7 min:0 max:65535 sd:19629.7
# 	12: "L4_SRC_PORT" NUMERICAL mean:32629.7 min:0 max:65535 sd:19169.1
# 	13: "OUT_BYTES" NUMERICAL mean:42198.6 min:0 max:1.40295e+07 sd:173983
# 	14: "OUT_PKTS" NUMERICAL mean:50.509 min:0 max:10402 sd:130.523
# 	15: "PROTOCOL_ARP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	16: "PROTOCOL_DCCP" NUMERICAL mean:3.69658e-05 min:0 max:1 sd:0.00607984
# 	17: "PROTOCOL_GRE" NUMERICAL mean:5.54488e-05 min:0 max:1 sd:0.00744619
# 	18: "PROTOCOL_HOPOPT" NUMERICAL mean:3.69658e-05 min:0 max:1 sd:0.00607984
# 	19: "PROTOCOL_ICMP" NUMERICAL mean:0.000480556 min:0 max:1 sd:0.0219163
# 	20: "PROTOCOL_IGMP" NUMERICAL mean:3.08049e-05 min:0 max:1 sd:0.00555013
# 	21: "PROTOCOL_IPv6" NUMERICAL mean:4.31268e-05 min:0 max:1 sd:0.00656696
# 	22: "PROTOCOL_IPv6-ICMP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	23: "PROTOCOL_OSPFIGP" NUMERICAL mean:0.0011213 min:0 max:1 sd:0.033467
# 	24: "PROTOCOL_OTHER" NUMERICAL mean:0.00576667 min:0 max:1 sd:0.0757193
# 	25: "PROTOCOL_PIM" NUMERICAL mean:6.77707e-05 min:0 max:1 sd:0.00823202
# 	26: "PROTOCOL_SCTP" NUMERICAL mean:4.31268e-05 min:0 max:1 sd:0.00656696
# 	27: "PROTOCOL_SUN-ND" NUMERICAL mean:3.08049e-05 min:0 max:1 sd:0.00555013
# 	28: "PROTOCOL_SWIPE" NUMERICAL mean:5.54488e-05 min:0 max:1 sd:0.00744619
# 	29: "PROTOCOL_TCP" NUMERICAL mean:0.720889 min:0 max:1 sd:0.448562
# 	30: "PROTOCOL_TLSP" NUMERICAL mean:3.69658e-05 min:0 max:1 sd:0.00607984
# 	31: "PROTOCOL_UDP" NUMERICAL mean:0.271305 min:0 max:1 sd:0.444633
#
# CATEGORICAL: 1 (3.0303%)
# 	32: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1738754156.598422    5704 kernel.cc:810] Configure learner
# I0000 00:00:1738754156.598561    5704 kernel.cc:824] Training config:
# learner: "RANDOM_FOREST"
# features: "^FLOW_DURATION_MILLISECONDS$"
# features: "^IN_BYTES$"
# features: "^IN_PKTS$"
# features: "^IPV4_DST_ADDR_octet0$"
# features: "^IPV4_DST_ADDR_octet1$"
# features: "^IPV4_DST_ADDR_octet2$"
# features: "^IPV4_DST_ADDR_octet3$"
# features: "^IPV4_SRC_ADDR_octet0$"
# features: "^IPV4_SRC_ADDR_octet1$"
# features: "^IPV4_SRC_ADDR_octet2$"
# features: "^IPV4_SRC_ADDR_octet3$"
# features: "^L4_DST_PORT$"
# features: "^L4_SRC_PORT$"
# features: "^OUT_BYTES$"
# features: "^OUT_PKTS$"
# features: "^PROTOCOL_ARP$"
# features: "^PROTOCOL_DCCP$"
# features: "^PROTOCOL_GRE$"
# features: "^PROTOCOL_HOPOPT$"
# features: "^PROTOCOL_ICMP$"
# features: "^PROTOCOL_IGMP$"
# features: "^PROTOCOL_IPv6$"
# features: "^PROTOCOL_IPv6\\-ICMP$"
# features: "^PROTOCOL_OSPFIGP$"
# features: "^PROTOCOL_OTHER$"
# features: "^PROTOCOL_PIM$"
# features: "^PROTOCOL_SCTP$"
# features: "^PROTOCOL_SUN\\-ND$"
# features: "^PROTOCOL_SWIPE$"
# features: "^PROTOCOL_TCP$"
# features: "^PROTOCOL_TLSP$"
# features: "^PROTOCOL_UDP$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 123456
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.random_forest.proto.random_forest_config] {
#   num_trees: 50
#   decision_tree {
#     max_depth: 10
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: 0
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: IN_NODE
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#   }
#   winner_take_all_inference: true
#   compute_oob_performances: true
#   compute_oob_variable_importances: false
#   num_oob_variable_importances_permutations: 1
#   bootstrap_training_dataset: true
#   bootstrap_size_ratio: 1
#   adapt_bootstrap_size_ratio_for_maximum_training_duration: false
#   sampling_with_replacement: true
# }
#
# I0000 00:00:1738754156.598834    5704 kernel.cc:827] Deployment config:
# cache_path: "/tmp/tmpr_ydorvq/working_cache"
# num_threads: 16
# try_resume_training: true
#
# I0000 00:00:1738754156.598970   10729 kernel.cc:888] Train model
# I0000 00:00:1738754156.599432   10729 random_forest.cc:428] Training random forest on 1298494 example(s) and 32 feature(s).
# I0000 00:00:1738754160.309073   10737 random_forest.cc:812] Training of tree  1/50 (tree index:7) done accuracy:0.987921 logloss:0.435386
# I0000 00:00:1738754162.021566   10730 random_forest.cc:812] Training of tree  11/50 (tree index:1) done accuracy:0.988824 logloss:0.258816
# I0000 00:00:1738754164.934802   10741 random_forest.cc:812] Training of tree  21/50 (tree index:21) done accuracy:0.989486 logloss:0.176589
# I0000 00:00:1738754167.421268   10738 random_forest.cc:812] Training of tree  31/50 (tree index:31) done accuracy:0.989516 logloss:0.163506
# I0000 00:00:1738754170.033592   10732 random_forest.cc:812] Training of tree  41/50 (tree index:43) done accuracy:0.989525 logloss:0.151858
# I0000 00:00:1738754171.157908   10739 random_forest.cc:812] Training of tree  50/50 (tree index:48) done accuracy:0.98957 logloss:0.133933
# I0000 00:00:1738754171.158312   10729 random_forest.cc:892] Final OOB metrics: accuracy:0.98957 logloss:0.133933
# I0000 00:00:1738754171.190164   10729 kernel.cc:920] Export model in log directory: /tmp/tmpr_ydorvq with prefix 2e3ff9311f1e4b0c
# I0000 00:00:1738754171.240415   10729 kernel.cc:938] Save model in resources
# I0000 00:00:1738754171.244169    5704 abstract_model.cc:833] Model self evaluation:
# Number of predictions (without weights): 1298494
# Number of predictions (with weights): 1.29849e+06
# Task: CLASSIFICATION
# Label: __LABEL
#
# Accuracy: 0.98957  CI95[W][0.989422 0.989716]
# LogLoss: : 0.133933
# ErrorRate: : 0.0104298
#
# Default Accuracy: : 0.955305
# Default LogLoss: : 0.182588
# Default ErrorRate: : 0.0446948
#
# Confusion Table:
# truth\prediction
#          1      2
# 1  1236244   4214
# 2     9329  48707
# Total: 1298494
#
#
# 2025-02-05 12:16:11.253971: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1234] Loading model from path /tmp/tmpr_ydorvq/model/ with prefix 2e3ff9311f1e4b0c
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738754171.276860    5704 decision_forest.cc:761] Model loaded with 50 root(s), 12198 node(s), and 27 input feature(s).
# I0000 00:00:1738754171.280172    5704 abstract_model.cc:1323] Engine "RandomForestOptPred" built
# 2025-02-05 12:16:11.280227: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1062] Use fast generic engine
# Training complete
# Loading NF-UNSW-NB15 testset
# (324624, 33)
# Loading complete
# Evaluating model trained on NF-UNSW-NB15 trainset on NF-UNSW-NB15 testset
# 635/635 [==============================] - 5s 7ms/step
# Evaluation complete
# Results for:...
# Model trained on NF-UNSW-NB15 and evaluated on NF-UNSW-NB15
# [[309234   1020]
#  [  2381  11989]]
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99    310254
#          1.0       0.92      0.83      0.88     14370
#
#     accuracy                           0.99    324624
#    macro avg       0.96      0.92      0.94    324624
# weighted avg       0.99      0.99      0.99    324624
#
# ---
# Loading NF-CSE-CIC-IDS2018 testset
# <timed exec>:73: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# (1678480, 33)
# Loading complete
# Evaluating model trained on NF-UNSW-NB15 trainset on NF-CSE-CIC-IDS2018 testset
# 3279/3279 [==============================] - 26s 8ms/step
# Evaluation complete
# Results for:...
# Model trained on NF-UNSW-NB15 and evaluated on NF-CSE-CIC-IDS2018
# [[1253838  221383]
#  [ 202079    1180]]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.85      0.86   1475221
#          1.0       0.01      0.01      0.01    203259
#
#     accuracy                           0.75   1678480
#    macro avg       0.43      0.43      0.43   1678480
# weighted avg       0.76      0.75      0.75   1678480
#
# ---
# Loading NF-BoT-IoT testset
# (120020, 33)
# Loading complete
# Evaluating model trained on NF-UNSW-NB15 trainset on NF-BoT-IoT testset
# 235/235 [==============================] - 2s 7ms/step
# Evaluation complete
# Results for:...
# Model trained on NF-UNSW-NB15 and evaluated on NF-BoT-IoT
# [[  2798      2]
#  [117219      1]]
#               precision    recall  f1-score   support
#
#          0.0       0.02      1.00      0.05      2800
#          1.0       0.33      0.00      0.00    117220
#
#     accuracy                           0.02    120020
#    macro avg       0.18      0.50      0.02    120020
# weighted avg       0.33      0.02      0.00    120020
#
# ---
# Loading NF-ToN-IoT testset
# (275855, 33)
# Loading complete
# Evaluating model trained on NF-UNSW-NB15 trainset on NF-ToN-IoT testset
# 539/539 [==============================] - 4s 7ms/step
# Evaluation complete
# Results for:...
# Model trained on NF-UNSW-NB15 and evaluated on NF-ToN-IoT
# [[ 50990   2934]
#  [208826  13105]]
#               precision    recall  f1-score   support
#
#          0.0       0.20      0.95      0.33     53924
#          1.0       0.82      0.06      0.11    221931
#
#     accuracy                           0.23    275855
#    macro avg       0.51      0.50      0.22    275855
# weighted avg       0.70      0.23      0.15    275855
#
# ---
# Loading X-IIoTiD testset
# (164018, 33)
# Loading complete
# Evaluating model trained on NF-UNSW-NB15 trainset on X-IIoTiD testset
# 321/321 [==============================] - 2s 8ms/step
# Evaluation complete
# Results for:...
# Model trained on NF-UNSW-NB15 and evaluated on X-IIoTiD
# [[72959 11111]
#  [78096  1852]]
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.87      0.62     84070
#          1.0       0.14      0.02      0.04     79948
#
#     accuracy                           0.46    164018
#    macro avg       0.31      0.45      0.33    164018
# weighted avg       0.32      0.46      0.34    164018
#
# ---
# Loading WUSTL-IIOT testset
# (238165, 33)
# Loading complete
# Evaluating model trained on NF-UNSW-NB15 trainset on WUSTL-IIOT testset
# 466/466 [==============================] - 3s 7ms/step
# Evaluation complete
# Results for:...
# Model trained on NF-UNSW-NB15 and evaluated on WUSTL-IIOT
# [[220810      1]
#  [ 17354      0]]
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.96    220811
#          1.0       0.00      0.00      0.00     17354
#
#     accuracy                           0.93    238165
#    macro avg       0.46      0.50      0.48    238165
# weighted avg       0.86      0.93      0.89    238165
#
# ---
# Cleanup complete
# ---+++---
# Loading NF-CSE-CIC-IDS2018 trainingset
# (6713919, 33)
# Loading complete
# Training on NF-CSE-CIC-IDS2018 trainingset
# Num validation examples: tf.Tensor(839240, shape=(), dtype=int32)
# I0000 00:00:1738754355.641130    5704 kernel.cc:774] Start Yggdrasil model training
# I0000 00:00:1738754355.641171    5704 kernel.cc:775] Collect training examples
# I0000 00:00:1738754355.641187    5704 kernel.cc:787] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: false
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1738754355.641459    5704 kernel.cc:394] Number of batches: 13114
# I0000 00:00:1738754355.641477    5704 kernel.cc:395] Number of examples: 6713919
# I0000 00:00:1738754356.866453    5704 kernel.cc:794] Training dataset:
# Number of records: 6713919
# Number of columns: 33
#
# Number of columns by type:
# 	NUMERICAL: 32 (96.9697%)
# 	CATEGORICAL: 1 (3.0303%)
#
# Columns:
#
# NUMERICAL: 32 (96.9697%)
# 	0: "FLOW_DURATION_MILLISECONDS" NUMERICAL mean:2.83199e+06 min:0 max:4.29497e+06 sd:2.03036e+06
# 	1: "IN_BYTES" NUMERICAL mean:3767.12 min:0 max:2.43713e+07 sd:130846
# 	2: "IN_PKTS" NUMERICAL mean:39.6987 min:0 max:228933 sd:1955.94
# 	3: "IPV4_DST_ADDR_octet0" NUMERICAL mean:144.528 min:0 max:255 sd:61.4089
# 	4: "IPV4_DST_ADDR_octet1" NUMERICAL mean:74.5168 min:0 max:255 sd:75.2341
# 	5: "IPV4_DST_ADDR_octet2" NUMERICAL mean:79.3768 min:0 max:255 sd:73.3808
# 	6: "IPV4_DST_ADDR_octet3" NUMERICAL mean:59.3993 min:0 max:255 sd:71.7095
# 	7: "IPV4_SRC_ADDR_octet0" NUMERICAL mean:144.008 min:0 max:223 sd:61.7707
# 	8: "IPV4_SRC_ADDR_octet1" NUMERICAL mean:72.1867 min:0 max:255 sd:71.2723
# 	9: "IPV4_SRC_ADDR_octet2" NUMERICAL mean:91.6534 min:0 max:255 sd:57.7007
# 	10: "IPV4_SRC_ADDR_octet3" NUMERICAL mean:61.1021 min:0 max:255 sd:57.6962
# 	11: "L4_DST_PORT" NUMERICAL mean:8404.33 min:0 max:65535 sd:17570
# 	12: "L4_SRC_PORT" NUMERICAL mean:42522.6 min:0 max:65535 sd:22012.7
# 	13: "OUT_BYTES" NUMERICAL mean:4365.43 min:0 max:2.14123e+08 sd:266919
# 	14: "OUT_PKTS" NUMERICAL mean:5.91204 min:0 max:142798 sd:183.765
# 	15: "PROTOCOL_ARP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	16: "PROTOCOL_DCCP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	17: "PROTOCOL_GRE" NUMERICAL mean:7.44722e-07 min:0 max:1 sd:0.000862972
# 	18: "PROTOCOL_HOPOPT" NUMERICAL mean:2.97889e-07 min:0 max:1 sd:0.000545792
# 	19: "PROTOCOL_ICMP" NUMERICAL mean:0.00462978 min:0 max:1 sd:0.0678848
# 	20: "PROTOCOL_IGMP" NUMERICAL mean:0.000722082 min:0 max:1 sd:0.0268619
# 	21: "PROTOCOL_IPv6" NUMERICAL mean:0 min:0 max:0 sd:0
# 	22: "PROTOCOL_IPv6-ICMP" NUMERICAL mean:0.000647759 min:0 max:1 sd:0.0254429
# 	23: "PROTOCOL_OSPFIGP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	24: "PROTOCOL_OTHER" NUMERICAL mean:0 min:0 max:0 sd:0
# 	25: "PROTOCOL_PIM" NUMERICAL mean:0 min:0 max:0 sd:0
# 	26: "PROTOCOL_SCTP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	27: "PROTOCOL_SUN-ND" NUMERICAL mean:0 min:0 max:0 sd:0
# 	28: "PROTOCOL_SWIPE" NUMERICAL mean:0 min:0 max:0 sd:0
# 	29: "PROTOCOL_TCP" NUMERICAL mean:0.735389 min:0 max:1 sd:0.441126
# 	30: "PROTOCOL_TLSP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	31: "PROTOCOL_UDP" NUMERICAL mean:0.25861 min:0 max:1 sd:0.437871
#
# CATEGORICAL: 1 (3.0303%)
# 	32: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1738754356.866532    5704 kernel.cc:799] Collect validation dataset
# I0000 00:00:1738754356.866659    5704 kernel.cc:394] Number of batches: 1640
# I0000 00:00:1738754356.866670    5704 kernel.cc:395] Number of examples: 839240
# I0000 00:00:1738754357.022642    5704 kernel.cc:805] Validation dataset:
# Number of records: 839240
# Number of columns: 33
#
# Number of columns by type:
# 	NUMERICAL: 32 (96.9697%)
# 	CATEGORICAL: 1 (3.0303%)
#
# Columns:
#
# NUMERICAL: 32 (96.9697%)
# 	0: "FLOW_DURATION_MILLISECONDS" NUMERICAL mean:2.83248e+06 min:0 max:4.29497e+06 sd:2.03019e+06
# 	1: "IN_BYTES" NUMERICAL mean:3950.01 min:28 max:1.67978e+07 sd:135780
# 	2: "IN_PKTS" NUMERICAL mean:42.1849 min:1 max:279963 sd:2056.23
# 	3: "IPV4_DST_ADDR_octet0" NUMERICAL mean:144.405 min:0 max:255 sd:61.4778
# 	4: "IPV4_DST_ADDR_octet1" NUMERICAL mean:74.5582 min:0 max:255 sd:75.2608
# 	5: "IPV4_DST_ADDR_octet2" NUMERICAL mean:79.3391 min:0 max:255 sd:73.3439
# 	6: "IPV4_DST_ADDR_octet3" NUMERICAL mean:59.3818 min:0 max:255 sd:71.7099
# 	7: "IPV4_SRC_ADDR_octet0" NUMERICAL mean:144.013 min:0 max:223 sd:61.7533
# 	8: "IPV4_SRC_ADDR_octet1" NUMERICAL mean:72.1003 min:0 max:255 sd:71.2231
# 	9: "IPV4_SRC_ADDR_octet2" NUMERICAL mean:91.5079 min:0 max:255 sd:57.6137
# 	10: "IPV4_SRC_ADDR_octet3" NUMERICAL mean:61.0307 min:0 max:255 sd:57.6476
# 	11: "L4_DST_PORT" NUMERICAL mean:8427.93 min:0 max:65535 sd:17601.5
# 	12: "L4_SRC_PORT" NUMERICAL mean:42525.3 min:0 max:65535 sd:22025.6
# 	13: "OUT_BYTES" NUMERICAL mean:4252.97 min:0 max:4.41144e+07 sd:212009
# 	14: "OUT_PKTS" NUMERICAL mean:5.82011 min:0 max:29495 sd:143.958
# 	15: "PROTOCOL_ARP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	16: "PROTOCOL_DCCP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	17: "PROTOCOL_GRE" NUMERICAL mean:0 min:0 max:0 sd:0
# 	18: "PROTOCOL_HOPOPT" NUMERICAL mean:0 min:0 max:0 sd:0
# 	19: "PROTOCOL_ICMP" NUMERICAL mean:0.00467208 min:0 max:1 sd:0.0681928
# 	20: "PROTOCOL_IGMP" NUMERICAL mean:0.000726848 min:0 max:1 sd:0.0269503
# 	21: "PROTOCOL_IPv6" NUMERICAL mean:0 min:0 max:0 sd:0
# 	22: "PROTOCOL_IPv6-ICMP" NUMERICAL mean:0.000666079 min:0 max:1 sd:0.0257999
# 	23: "PROTOCOL_OSPFIGP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	24: "PROTOCOL_OTHER" NUMERICAL mean:0 min:0 max:0 sd:0
# 	25: "PROTOCOL_PIM" NUMERICAL mean:0 min:0 max:0 sd:0
# 	26: "PROTOCOL_SCTP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	27: "PROTOCOL_SUN-ND" NUMERICAL mean:0 min:0 max:0 sd:0
# 	28: "PROTOCOL_SWIPE" NUMERICAL mean:0 min:0 max:0 sd:0
# 	29: "PROTOCOL_TCP" NUMERICAL mean:0.735234 min:0 max:1 sd:0.441208
# 	30: "PROTOCOL_TLSP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	31: "PROTOCOL_UDP" NUMERICAL mean:0.258701 min:0 max:1 sd:0.437921
#
# CATEGORICAL: 1 (3.0303%)
# 	32: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1738754357.022724    5704 kernel.cc:810] Configure learner
# I0000 00:00:1738754357.022924    5704 kernel.cc:824] Training config:
# learner: "RANDOM_FOREST"
# features: "^FLOW_DURATION_MILLISECONDS$"
# features: "^IN_BYTES$"
# features: "^IN_PKTS$"
# features: "^IPV4_DST_ADDR_octet0$"
# features: "^IPV4_DST_ADDR_octet1$"
# features: "^IPV4_DST_ADDR_octet2$"
# features: "^IPV4_DST_ADDR_octet3$"
# features: "^IPV4_SRC_ADDR_octet0$"
# features: "^IPV4_SRC_ADDR_octet1$"
# features: "^IPV4_SRC_ADDR_octet2$"
# features: "^IPV4_SRC_ADDR_octet3$"
# features: "^L4_DST_PORT$"
# features: "^L4_SRC_PORT$"
# features: "^OUT_BYTES$"
# features: "^OUT_PKTS$"
# features: "^PROTOCOL_ARP$"
# features: "^PROTOCOL_DCCP$"
# features: "^PROTOCOL_GRE$"
# features: "^PROTOCOL_HOPOPT$"
# features: "^PROTOCOL_ICMP$"
# features: "^PROTOCOL_IGMP$"
# features: "^PROTOCOL_IPv6$"
# features: "^PROTOCOL_IPv6\\-ICMP$"
# features: "^PROTOCOL_OSPFIGP$"
# features: "^PROTOCOL_OTHER$"
# features: "^PROTOCOL_PIM$"
# features: "^PROTOCOL_SCTP$"
# features: "^PROTOCOL_SUN\\-ND$"
# features: "^PROTOCOL_SWIPE$"
# features: "^PROTOCOL_TCP$"
# features: "^PROTOCOL_TLSP$"
# features: "^PROTOCOL_UDP$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 123456
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.random_forest.proto.random_forest_config] {
#   num_trees: 50
#   decision_tree {
#     max_depth: 10
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: 0
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: IN_NODE
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#   }
#   winner_take_all_inference: true
#   compute_oob_performances: true
#   compute_oob_variable_importances: false
#   num_oob_variable_importances_permutations: 1
#   bootstrap_training_dataset: true
#   bootstrap_size_ratio: 1
#   adapt_bootstrap_size_ratio_for_maximum_training_duration: false
#   sampling_with_replacement: true
# }
#
# I0000 00:00:1738754357.023003    5704 kernel.cc:827] Deployment config:
# cache_path: "/tmp/tmprquptklk/working_cache"
# num_threads: 16
# try_resume_training: true
#
# I0000 00:00:1738754357.023150   11602 kernel.cc:888] Train model
# I0000 00:00:1738754357.023725   11602 random_forest.cc:428] Training random forest on 6713919 example(s) and 32 feature(s).
# I0000 00:00:1738754431.706708   11612 random_forest.cc:812] Training of tree  1/50 (tree index:11) done accuracy:0.993652 logloss:0.228788
# I0000 00:00:1738754442.534595   11610 random_forest.cc:812] Training of tree  4/50 (tree index:9) done accuracy:0.993584 logloss:0.205769
# I0000 00:00:1738754454.151737   11613 random_forest.cc:812] Training of tree  10/50 (tree index:12) done accuracy:0.993373 logloss:0.183068
# I0000 00:00:1738754465.138578   11617 random_forest.cc:812] Training of tree  14/50 (tree index:0) done accuracy:0.993357 logloss:0.176904
# I0000 00:00:1738754516.790526   11606 random_forest.cc:812] Training of tree  17/50 (tree index:18) done accuracy:0.993404 logloss:0.174681
# I0000 00:00:1738754529.404410   11611 random_forest.cc:812] Training of tree  21/50 (tree index:23) done accuracy:0.993418 logloss:0.172308
# I0000 00:00:1738754541.063084   11615 random_forest.cc:812] Training of tree  24/50 (tree index:20) done accuracy:0.993487 logloss:0.168256
# I0000 00:00:1738754551.195540   11604 random_forest.cc:812] Training of tree  28/50 (tree index:26) done accuracy:0.993436 logloss:0.167092
# I0000 00:00:1738754563.983969   11603 random_forest.cc:812] Training of tree  32/50 (tree index:30) done accuracy:0.993449 logloss:0.164971
# I0000 00:00:1738754606.298912   11604 random_forest.cc:812] Training of tree  33/50 (tree index:43) done accuracy:0.993469 logloss:0.164195
# I0000 00:00:1738754619.667725   11605 random_forest.cc:812] Training of tree  39/50 (tree index:38) done accuracy:0.99347 logloss:0.163687
# I0000 00:00:1738754635.187399   11604 random_forest.cc:812] Training of tree  49/50 (tree index:48) done accuracy:0.993467 logloss:0.162263
# I0000 00:00:1738754637.215663   11610 random_forest.cc:812] Training of tree  50/50 (tree index:49) done accuracy:0.993463 logloss:0.162286
# I0000 00:00:1738754637.250143   11602 random_forest.cc:892] Final OOB metrics: accuracy:0.993463 logloss:0.162286
# I0000 00:00:1738754637.343392   11602 kernel.cc:920] Export model in log directory: /tmp/tmprquptklk with prefix 7b02659185cc471f
# I0000 00:00:1738754637.362392   11602 kernel.cc:938] Save model in resources
# I0000 00:00:1738754637.519060    5704 abstract_model.cc:833] Model self evaluation:
# Number of predictions (without weights): 6713919
# Number of predictions (with weights): 6.71392e+06
# Task: CLASSIFICATION
# Label: __LABEL
#
# Accuracy: 0.993463  CI95[W][0.993412 0.993514]
# LogLoss: : 0.162286
# ErrorRate: : 0.00653702
#
# Default Accuracy: : 0.87847
# Default LogLoss: : 0.369963
# Default ErrorRate: : 0.12153
#
# Confusion Table:
# truth\prediction
#          1       2
# 1  5897882      93
# 2    43796  772148
# Total: 6713919
#
#
# 2025-02-05 12:23:57.542318: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1234] Loading model from path /tmp/tmprquptklk/model/ with prefix 7b02659185cc471f
# I0000 00:00:1738754637.575672    5704 decision_forest.cc:761] Model loaded with 50 root(s), 14104 node(s), and 18 input feature(s).
# I0000 00:00:1738754637.575900    5704 abstract_model.cc:1323] Engine "RandomForestOptPred" built
# 2025-02-05 12:23:57.575919: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1062] Use fast generic engine
# Training complete
# Loading NF-UNSW-NB15 testset
# (324624, 33)
# Loading complete
# Evaluating model trained on NF-CSE-CIC-IDS2018 trainset on NF-UNSW-NB15 testset
# 635/635 [==============================] - 5s 7ms/step
# Evaluation complete
# Results for:...
# Model trained on NF-CSE-CIC-IDS2018 and evaluated on NF-UNSW-NB15
# [[310254      0]
#  [ 14370      0]]
# /home/philip/anaconda3/envs/keras2/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/philip/anaconda3/envs/keras2/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/philip/anaconda3/envs/keras2/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98    310254
#          1.0       0.00      0.00      0.00     14370
#
#     accuracy                           0.96    324624
#    macro avg       0.48      0.50      0.49    324624
# weighted avg       0.91      0.96      0.93    324624
#
# ---
# Loading NF-CSE-CIC-IDS2018 testset
# (1678480, 33)
# Loading complete
# Evaluating model trained on NF-CSE-CIC-IDS2018 trainset on NF-CSE-CIC-IDS2018 testset
# 3279/3279 [==============================] - 26s 8ms/step
# Evaluation complete
# Results for:...
# Model trained on NF-CSE-CIC-IDS2018 and evaluated on NF-CSE-CIC-IDS2018
# [[1475216       5]
#  [  10955  192304]]
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00   1475221
#          1.0       1.00      0.95      0.97    203259
#
#     accuracy                           0.99   1678480
#    macro avg       1.00      0.97      0.98   1678480
# weighted avg       0.99      0.99      0.99   1678480
#
# ---
# Loading NF-BoT-IoT testset
# (120020, 33)
# Loading complete
# Evaluating model trained on NF-CSE-CIC-IDS2018 trainset on NF-BoT-IoT testset
# 235/235 [==============================] - 2s 8ms/step
# Evaluation complete
# Results for:...
# Model trained on NF-CSE-CIC-IDS2018 and evaluated on NF-BoT-IoT
# [[  2800      0]
#  [117220      0]]
#               precision    recall  f1-score   support
#
#          0.0       0.02      1.00      0.05      2800
#          1.0       0.00      0.00      0.00    117220
#
#     accuracy                           0.02    120020
#    macro avg       0.01      0.50      0.02    120020
# weighted avg       0.00      0.02      0.00    120020
# /home/philip/anaconda3/envs/keras2/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/philip/anaconda3/envs/keras2/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/philip/anaconda3/envs/keras2/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ---
# Loading NF-ToN-IoT testset
# (275855, 33)
# Loading complete
# Evaluating model trained on NF-CSE-CIC-IDS2018 trainset on NF-ToN-IoT testset
# 539/539 [==============================] - 4s 7ms/step
# Evaluation complete
# Results for:...
# Model trained on NF-CSE-CIC-IDS2018 and evaluated on NF-ToN-IoT
# [[ 53924      0]
#  [221931      0]]
# /home/philip/anaconda3/envs/keras2/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/philip/anaconda3/envs/keras2/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/philip/anaconda3/envs/keras2/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.20      1.00      0.33     53924
#          1.0       0.00      0.00      0.00    221931
#
#     accuracy                           0.20    275855
#    macro avg       0.10      0.50      0.16    275855
# weighted avg       0.04      0.20      0.06    275855
#
# ---
# Loading X-IIoTiD testset
# (164018, 33)
# Loading complete
# Evaluating model trained on NF-CSE-CIC-IDS2018 trainset on X-IIoTiD testset
# 321/321 [==============================] - 3s 8ms/step
# Evaluation complete
# Results for:...
# Model trained on NF-CSE-CIC-IDS2018 and evaluated on X-IIoTiD
# [[84070     0]
#  [79948     0]]
# /home/philip/anaconda3/envs/keras2/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/philip/anaconda3/envs/keras2/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/philip/anaconda3/envs/keras2/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.51      1.00      0.68     84070
#          1.0       0.00      0.00      0.00     79948
#
#     accuracy                           0.51    164018
#    macro avg       0.26      0.50      0.34    164018
# weighted avg       0.26      0.51      0.35    164018
#
# ---
# Loading WUSTL-IIOT testset
# (238165, 33)
# Loading complete
# Evaluating model trained on NF-CSE-CIC-IDS2018 trainset on WUSTL-IIOT testset
# 466/466 [==============================] - 4s 7ms/step
# Evaluation complete
# Results for:...
# Model trained on NF-CSE-CIC-IDS2018 and evaluated on WUSTL-IIOT
# [[220811      0]
#  [ 17354      0]]
# /home/philip/anaconda3/envs/keras2/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/philip/anaconda3/envs/keras2/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/philip/anaconda3/envs/keras2/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.96    220811
#          1.0       0.00      0.00      0.00     17354
#
#     accuracy                           0.93    238165
#    macro avg       0.46      0.50      0.48    238165
# weighted avg       0.86      0.93      0.89    238165
#
# ---
# Cleanup complete
# ---+++---
# Loading NF-BoT-IoT trainingset
# (480080, 33)
# Loading complete
# Training on NF-BoT-IoT trainingset
# Num validation examples: tf.Tensor(60010, shape=(), dtype=int32)
# I0000 00:00:1738754717.593387    5704 kernel.cc:774] Start Yggdrasil model training
# I0000 00:00:1738754717.593415    5704 kernel.cc:775] Collect training examples
# I0000 00:00:1738754717.593427    5704 kernel.cc:787] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: false
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1738754717.594344    5704 kernel.cc:394] Number of batches: 938
# I0000 00:00:1738754717.594365    5704 kernel.cc:395] Number of examples: 480080
# I0000 00:00:1738754717.708767    5704 kernel.cc:794] Training dataset:
# Number of records: 480080
# Number of columns: 33
#
# Number of columns by type:
# 	NUMERICAL: 32 (96.9697%)
# 	CATEGORICAL: 1 (3.0303%)
#
# Columns:
#
# NUMERICAL: 32 (96.9697%)
# 	0: "FLOW_DURATION_MILLISECONDS" NUMERICAL mean:3.46933e+06 min:0 max:4.29497e+06 sd:1.66479e+06
# 	1: "IN_BYTES" NUMERICAL mean:9193.34 min:28 max:2.28223e+08 sd:414028
# 	2: "IN_PKTS" NUMERICAL mean:12.6542 min:1 max:37817 sd:251.038
# 	3: "IPV4_DST_ADDR_octet0" NUMERICAL mean:191.501 min:0 max:255 sd:9.51567
# 	4: "IPV4_DST_ADDR_octet1" NUMERICAL mean:167.618 min:0 max:255 sd:8.28021
# 	5: "IPV4_DST_ADDR_octet2" NUMERICAL mean:100.081 min:0 max:255 sd:6.96305
# 	6: "IPV4_DST_ADDR_octet3" NUMERICAL mean:7.22011 min:0 max:255 sd:19.1044
# 	7: "IPV4_SRC_ADDR_octet0" NUMERICAL mean:191.991 min:0 max:192 sd:1.27036
# 	8: "IPV4_SRC_ADDR_octet1" NUMERICAL mean:167.993 min:0 max:236 sd:1.09087
# 	9: "IPV4_SRC_ADDR_octet2" NUMERICAL mean:99.9959 min:0 max:114 sd:0.646019
# 	10: "IPV4_SRC_ADDR_octet3" NUMERICAL mean:145.546 min:0 max:150 sd:19.9743
# 	11: "L4_DST_PORT" NUMERICAL mean:7953.25 min:0 max:65535 sd:14106.8
# 	12: "L4_SRC_PORT" NUMERICAL mean:46522 min:0 max:65535 sd:12035.6
# 	13: "OUT_BYTES" NUMERICAL mean:7391.64 min:0 max:2.4322e+08 sd:867025
# 	14: "OUT_PKTS" NUMERICAL mean:5.79092 min:0 max:61110 sd:199.948
# 	15: "PROTOCOL_ARP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	16: "PROTOCOL_DCCP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	17: "PROTOCOL_GRE" NUMERICAL mean:0 min:0 max:0 sd:0
# 	18: "PROTOCOL_HOPOPT" NUMERICAL mean:0 min:0 max:0 sd:0
# 	19: "PROTOCOL_ICMP" NUMERICAL mean:0.00618855 min:0 max:1 sd:0.0784236
# 	20: "PROTOCOL_IGMP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	21: "PROTOCOL_IPv6" NUMERICAL mean:0 min:0 max:0 sd:0
# 	22: "PROTOCOL_IPv6-ICMP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	23: "PROTOCOL_OSPFIGP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	24: "PROTOCOL_OTHER" NUMERICAL mean:0 min:0 max:0 sd:0
# 	25: "PROTOCOL_PIM" NUMERICAL mean:0 min:0 max:0 sd:0
# 	26: "PROTOCOL_SCTP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	27: "PROTOCOL_SUN-ND" NUMERICAL mean:0 min:0 max:0 sd:0
# 	28: "PROTOCOL_SWIPE" NUMERICAL mean:0 min:0 max:0 sd:0
# 	29: "PROTOCOL_TCP" NUMERICAL mean:0.938075 min:0 max:1 sd:0.241019
# 	30: "PROTOCOL_TLSP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	31: "PROTOCOL_UDP" NUMERICAL mean:0.0557365 min:0 max:1 sd:0.229412
#
# CATEGORICAL: 1 (3.0303%)
# 	32: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1738754717.708859    5704 kernel.cc:799] Collect validation dataset
# I0000 00:00:1738754717.708962    5704 kernel.cc:394] Number of batches: 118
# I0000 00:00:1738754717.708971    5704 kernel.cc:395] Number of examples: 60010
# I0000 00:00:1738754717.720007    5704 kernel.cc:805] Validation dataset:
# Number of records: 60010
# Number of columns: 33
#
# Number of columns by type:
# 	NUMERICAL: 32 (96.9697%)
# 	CATEGORICAL: 1 (3.0303%)
#
# Columns:
#
# NUMERICAL: 32 (96.9697%)
# 	0: "FLOW_DURATION_MILLISECONDS" NUMERICAL mean:3.47757e+06 min:0 max:4.29497e+06 sd:1.6591e+06
# 	1: "IN_BYTES" NUMERICAL mean:9546.85 min:28 max:7.56343e+07 sd:376010
# 	2: "IN_PKTS" NUMERICAL mean:12.3762 min:1 max:9599 sd:238.786
# 	3: "IPV4_DST_ADDR_octet0" NUMERICAL mean:191.534 min:0 max:224 sd:9.19989
# 	4: "IPV4_DST_ADDR_octet1" NUMERICAL mean:167.674 min:0 max:251 sd:7.80498
# 	5: "IPV4_DST_ADDR_octet2" NUMERICAL mean:100.064 min:0 max:239 sd:6.52083
# 	6: "IPV4_DST_ADDR_octet3" NUMERICAL mean:7.22825 min:0 max:255 sd:19.0877
# 	7: "IPV4_SRC_ADDR_octet0" NUMERICAL mean:191.994 min:0 max:192 sd:1.07153
# 	8: "IPV4_SRC_ADDR_octet1" NUMERICAL mean:167.998 min:0 max:236 sd:0.739846
# 	9: "IPV4_SRC_ADDR_octet2" NUMERICAL mean:99.9986 min:0 max:113 sd:0.411647
# 	10: "IPV4_SRC_ADDR_octet3" NUMERICAL mean:145.549 min:0 max:150 sd:19.9717
# 	11: "L4_DST_PORT" NUMERICAL mean:8017.02 min:0 max:65535 sd:14162.8
# 	12: "L4_SRC_PORT" NUMERICAL mean:46492.9 min:0 max:65535 sd:12064.2
# 	13: "OUT_BYTES" NUMERICAL mean:8151.93 min:0 max:2.20367e+08 sd:914979
# 	14: "OUT_PKTS" NUMERICAL mean:6.17249 min:0 max:9599 sd:175.105
# 	15: "PROTOCOL_ARP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	16: "PROTOCOL_DCCP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	17: "PROTOCOL_GRE" NUMERICAL mean:0 min:0 max:0 sd:0
# 	18: "PROTOCOL_HOPOPT" NUMERICAL mean:0 min:0 max:0 sd:0
# 	19: "PROTOCOL_ICMP" NUMERICAL mean:0.00571571 min:0 max:1 sd:0.075386
# 	20: "PROTOCOL_IGMP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	21: "PROTOCOL_IPv6" NUMERICAL mean:0 min:0 max:0 sd:0
# 	22: "PROTOCOL_IPv6-ICMP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	23: "PROTOCOL_OSPFIGP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	24: "PROTOCOL_OTHER" NUMERICAL mean:0 min:0 max:0 sd:0
# 	25: "PROTOCOL_PIM" NUMERICAL mean:0 min:0 max:0 sd:0
# 	26: "PROTOCOL_SCTP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	27: "PROTOCOL_SUN-ND" NUMERICAL mean:0 min:0 max:0 sd:0
# 	28: "PROTOCOL_SWIPE" NUMERICAL mean:0 min:0 max:0 sd:0
# 	29: "PROTOCOL_TCP" NUMERICAL mean:0.939393 min:0 max:1 sd:0.238607
# 	30: "PROTOCOL_TLSP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	31: "PROTOCOL_UDP" NUMERICAL mean:0.0548909 min:0 max:1 sd:0.227767
#
# CATEGORICAL: 1 (3.0303%)
# 	32: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1738754717.720092    5704 kernel.cc:810] Configure learner
# I0000 00:00:1738754717.720282    5704 kernel.cc:824] Training config:
# learner: "RANDOM_FOREST"
# features: "^FLOW_DURATION_MILLISECONDS$"
# features: "^IN_BYTES$"
# features: "^IN_PKTS$"
# features: "^IPV4_DST_ADDR_octet0$"
# features: "^IPV4_DST_ADDR_octet1$"
# features: "^IPV4_DST_ADDR_octet2$"
# features: "^IPV4_DST_ADDR_octet3$"
# features: "^IPV4_SRC_ADDR_octet0$"
# features: "^IPV4_SRC_ADDR_octet1$"
# features: "^IPV4_SRC_ADDR_octet2$"
# features: "^IPV4_SRC_ADDR_octet3$"
# features: "^L4_DST_PORT$"
# features: "^L4_SRC_PORT$"
# features: "^OUT_BYTES$"
# features: "^OUT_PKTS$"
# features: "^PROTOCOL_ARP$"
# features: "^PROTOCOL_DCCP$"
# features: "^PROTOCOL_GRE$"
# features: "^PROTOCOL_HOPOPT$"
# features: "^PROTOCOL_ICMP$"
# features: "^PROTOCOL_IGMP$"
# features: "^PROTOCOL_IPv6$"
# features: "^PROTOCOL_IPv6\\-ICMP$"
# features: "^PROTOCOL_OSPFIGP$"
# features: "^PROTOCOL_OTHER$"
# features: "^PROTOCOL_PIM$"
# features: "^PROTOCOL_SCTP$"
# features: "^PROTOCOL_SUN\\-ND$"
# features: "^PROTOCOL_SWIPE$"
# features: "^PROTOCOL_TCP$"
# features: "^PROTOCOL_TLSP$"
# features: "^PROTOCOL_UDP$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 123456
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.random_forest.proto.random_forest_config] {
#   num_trees: 50
#   decision_tree {
#     max_depth: 10
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: 0
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: IN_NODE
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#   }
#   winner_take_all_inference: true
#   compute_oob_performances: true
#   compute_oob_variable_importances: false
#   num_oob_variable_importances_permutations: 1
#   bootstrap_training_dataset: true
#   bootstrap_size_ratio: 1
#   adapt_bootstrap_size_ratio_for_maximum_training_duration: false
#   sampling_with_replacement: true
# }
#
# I0000 00:00:1738754717.720348    5704 kernel.cc:827] Deployment config:
# cache_path: "/tmp/tmp2b646e7b/working_cache"
# num_threads: 16
# try_resume_training: true
#
# I0000 00:00:1738754717.720458   12876 kernel.cc:888] Train model
# I0000 00:00:1738754717.720957   12876 random_forest.cc:428] Training random forest on 480080 example(s) and 32 feature(s).
# I0000 00:00:1738754722.252009   12877 random_forest.cc:812] Training of tree  1/50 (tree index:1) done accuracy:0.991336 logloss:0.312298
# ...
# Num validation examples: tf.Tensor(119083, shape=(), dtype=int32)
# I0000 00:00:1738755024.064419    5704 kernel.cc:774] Start Yggdrasil model training
# I0000 00:00:1738755024.064463    5704 kernel.cc:775] Collect training examples
# I0000 00:00:1738755024.064482    5704 kernel.cc:787] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: false
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1738755024.064759    5704 kernel.cc:394] Number of batches: 1861
# I0000 00:00:1738755024.064778    5704 kernel.cc:395] Number of examples: 952656
# I0000 00:00:1738755024.265976    5704 kernel.cc:794] Training dataset:
# Number of records: 952656
# Number of columns: 33
#
# Number of columns by type:
# 	NUMERICAL: 32 (96.9697%)
# 	CATEGORICAL: 1 (3.0303%)
#
# Columns:
#
# NUMERICAL: 32 (96.9697%)
# 	0: "FLOW_DURATION_MILLISECONDS" NUMERICAL mean:0.199022 min:0 max:5.10321 sd:0.797008
# 	1: "IN_BYTES" NUMERICAL mean:7494.16 min:0 max:8.25156e+07 sd:744958
# 	2: "IN_PKTS" NUMERICAL mean:9.14373 min:0 max:10184 sd:106.698
# 	3: "IPV4_DST_ADDR_octet0" NUMERICAL mean:192.092 min:0 max:255 sd:3.34219
# 	4: "IPV4_DST_ADDR_octet1" NUMERICAL mean:168.131 min:0 max:255 sd:4.29106
# 	5: "IPV4_DST_ADDR_octet2" NUMERICAL mean:0.465215 min:0 max:255 sd:10.8818
# 	6: "IPV4_DST_ADDR_octet3" NUMERICAL mean:3.66548 min:0 max:255 sd:18.3099
# 	7: "IPV4_SRC_ADDR_octet0" NUMERICAL mean:190.775 min:0 max:209 sd:17.7526
# 	8: "IPV4_SRC_ADDR_octet1" NUMERICAL mean:169.099 min:0 max:240 sd:21.4794
# 	9: "IPV4_SRC_ADDR_octet2" NUMERICAL mean:11.4545 min:0 max:249 sd:50.1011
# 	10: "IPV4_SRC_ADDR_octet3" NUMERICAL mean:23.275 min:0 max:92 sd:15.1847
# 	11: "L4_DST_PORT" NUMERICAL mean:790.055 min:0 max:65522 sd:3287.47
# 	12: "L4_SRC_PORT" NUMERICAL mean:54607.9 min:0 max:65534 sd:11393
# 	13: "OUT_BYTES" NUMERICAL mean:932.648 min:0 max:679184 sd:7854.36
# 	14: "OUT_PKTS" NUMERICAL mean:12.1599 min:0 max:9988 sd:105.868
# 	15: "PROTOCOL_ARP" NUMERICAL mean:0.00711065 min:0 max:1 sd:0.0840243
# 	16: "PROTOCOL_DCCP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	17: "PROTOCOL_GRE" NUMERICAL mean:0 min:0 max:0 sd:0
# 	18: "PROTOCOL_HOPOPT" NUMERICAL mean:0 min:0 max:0 sd:0
# 	19: "PROTOCOL_ICMP" NUMERICAL mean:8.39757e-06 min:0 max:1 sd:0.00289784
# 	20: "PROTOCOL_IGMP" NUMERICAL mean:0.00010497 min:0 max:1 sd:0.0102449
# 	21: "PROTOCOL_IPv6" NUMERICAL mean:0 min:0 max:0 sd:0
# 	22: "PROTOCOL_IPv6-ICMP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	23: "PROTOCOL_OSPFIGP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	24: "PROTOCOL_OTHER" NUMERICAL mean:0 min:0 max:0 sd:0
# 	25: "PROTOCOL_PIM" NUMERICAL mean:0 min:0 max:0 sd:0
# 	26: "PROTOCOL_SCTP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	27: "PROTOCOL_SUN-ND" NUMERICAL mean:0 min:0 max:0 sd:0
# 	28: "PROTOCOL_SWIPE" NUMERICAL mean:0 min:0 max:0 sd:0
# 	29: "PROTOCOL_TCP" NUMERICAL mean:0.96907 min:0 max:1 sd:0.173129
# 	30: "PROTOCOL_TLSP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	31: "PROTOCOL_UDP" NUMERICAL mean:0.0237064 min:0 max:1 sd:0.152133
#
# CATEGORICAL: 1 (3.0303%)
# 	32: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1738755024.266069    5704 kernel.cc:799] Collect validation dataset
# I0000 00:00:1738755024.266172    5704 kernel.cc:394] Number of batches: 233
# I0000 00:00:1738755024.266182    5704 kernel.cc:395] Number of examples: 119083
# I0000 00:00:1738755024.287557    5704 kernel.cc:805] Validation dataset:
# Number of records: 119083
# Number of columns: 33
#
# Number of columns by type:
# 	NUMERICAL: 32 (96.9697%)
# 	CATEGORICAL: 1 (3.0303%)
#
# Columns:
#
# NUMERICAL: 32 (96.9697%)
# 	0: "FLOW_DURATION_MILLISECONDS" NUMERICAL mean:0.197579 min:0 max:5.10321 sd:0.793996
# 	1: "IN_BYTES" NUMERICAL mean:6821.08 min:0 max:8.24473e+07 sd:710821
# 	2: "IN_PKTS" NUMERICAL mean:8.9386 min:0 max:10164 sd:100.994
# 	3: "IPV4_DST_ADDR_octet0" NUMERICAL mean:192.091 min:0 max:255 sd:3.36423
# 	4: "IPV4_DST_ADDR_octet1" NUMERICAL mean:168.135 min:0 max:255 sd:4.21945
# 	5: "IPV4_DST_ADDR_octet2" NUMERICAL mean:0.464676 min:0 max:255 sd:10.8755
# 	6: "IPV4_DST_ADDR_octet3" NUMERICAL mean:3.66323 min:1 max:255 sd:18.3035
# 	7: "IPV4_SRC_ADDR_octet0" NUMERICAL mean:190.831 min:0 max:209 sd:17.465
# 	8: "IPV4_SRC_ADDR_octet1" NUMERICAL mean:169.126 min:0 max:240 sd:21.1793
# 	9: "IPV4_SRC_ADDR_octet2" NUMERICAL mean:11.2068 min:0 max:249 sd:49.568
# 	10: "IPV4_SRC_ADDR_octet3" NUMERICAL mean:23.1923 min:0 max:92 sd:15.0545
# 	11: "L4_DST_PORT" NUMERICAL mean:789.768 min:0 max:65498 sd:3300.82
# 	12: "L4_SRC_PORT" NUMERICAL mean:54613.7 min:0 max:65534 sd:11367
# 	13: "OUT_BYTES" NUMERICAL mean:914.052 min:0 max:678776 sd:7466.47
# 	14: "OUT_PKTS" NUMERICAL mean:11.9701 min:0 max:9982 sd:100.229
# 	15: "PROTOCOL_ARP" NUMERICAL mean:0.00688595 min:0 max:1 sd:0.0826954
# 	16: "PROTOCOL_DCCP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	17: "PROTOCOL_GRE" NUMERICAL mean:0 min:0 max:0 sd:0
# 	18: "PROTOCOL_HOPOPT" NUMERICAL mean:0 min:0 max:0 sd:0
# 	19: "PROTOCOL_ICMP" NUMERICAL mean:8.3975e-06 min:0 max:1 sd:0.00289783
# 	20: "PROTOCOL_IGMP" NUMERICAL mean:0.000117565 min:0 max:1 sd:0.0108421
# 	21: "PROTOCOL_IPv6" NUMERICAL mean:0 min:0 max:0 sd:0
# 	22: "PROTOCOL_IPv6-ICMP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	23: "PROTOCOL_OSPFIGP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	24: "PROTOCOL_OTHER" NUMERICAL mean:0 min:0 max:0 sd:0
# 	25: "PROTOCOL_PIM" NUMERICAL mean:0 min:0 max:0 sd:0
# 	26: "PROTOCOL_SCTP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	27: "PROTOCOL_SUN-ND" NUMERICAL mean:0 min:0 max:0 sd:0
# 	28: "PROTOCOL_SWIPE" NUMERICAL mean:0 min:0 max:0 sd:0
# 	29: "PROTOCOL_TCP" NUMERICAL mean:0.96924 min:0 max:1 sd:0.172667
# 	30: "PROTOCOL_TLSP" NUMERICAL mean:0 min:0 max:0 sd:0
# 	31: "PROTOCOL_UDP" NUMERICAL mean:0.0237481 min:0 max:1 sd:0.152263
#
# CATEGORICAL: 1 (3.0303%)
# 	32: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1738755024.287601    5704 kernel.cc:810] Configure learner
# I0000 00:00:1738755024.287737    5704 kernel.cc:824] Training config:
# learner: "RANDOM_FOREST"
# features: "^FLOW_DURATION_MILLISECONDS$"
# features: "^IN_BYTES$"
# features: "^IN_PKTS$"
# features: "^IPV4_DST_ADDR_octet0$"
# features: "^IPV4_DST_ADDR_octet1$"
# features: "^IPV4_DST_ADDR_octet2$"
# features: "^IPV4_DST_ADDR_octet3$"
# features: "^IPV4_SRC_ADDR_octet0$"
# features: "^IPV4_SRC_ADDR_octet1$"
# features: "^IPV4_SRC_ADDR_octet2$"
# features: "^IPV4_SRC_ADDR_octet3$"
# features: "^L4_DST_PORT$"
# features: "^L4_SRC_PORT$"
# features: "^OUT_BYTES$"
# features: "^OUT_PKTS$"
# features: "^PROTOCOL_ARP$"
# features: "^PROTOCOL_DCCP$"
# features: "^PROTOCOL_GRE$"
# features: "^PROTOCOL_HOPOPT$"
# features: "^PROTOCOL_ICMP$"
# features: "^PROTOCOL_IGMP$"
# features: "^PROTOCOL_IPv6$"
# features: "^PROTOCOL_IPv6\\-ICMP$"
# features: "^PROTOCOL_OSPFIGP$"
# features: "^PROTOCOL_OTHER$"
# features: "^PROTOCOL_PIM$"
# features: "^PROTOCOL_SCTP$"
# features: "^PROTOCOL_SUN\\-ND$"
# features: "^PROTOCOL_SWIPE$"
# features: "^PROTOCOL_TCP$"
# features: "^PROTOCOL_TLSP$"
# features: "^PROTOCOL_UDP$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 123456
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.random_forest.proto.random_forest_config] {
#   num_trees: 50
#   decision_tree {
#     max_depth: 10
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: 0
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: IN_NODE
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#   }
#   winner_take_all_inference: true
#   compute_oob_performances: true
#   compute_oob_variable_importances: false
#   num_oob_variable_importances_permutations: 1
#   bootstrap_training_dataset: true
#   bootstrap_size_ratio: 1
#   adapt_bootstrap_size_ratio_for_maximum_training_duration: false
#   sampling_with_replacement: true
# }
#
# I0000 00:00:1738755024.287806    5704 kernel.cc:827] Deployment config:
# cache_path: "/tmp/tmpmw58877v/working_cache"
# num_threads: 16
# try_resume_training: true
#
# I0000 00:00:1738755024.287916   14812 kernel.cc:888] Train model
# I0000 00:00:1738755024.288517   14812 random_forest.cc:428] Training random forest on 952656 example(s) and 32 feature(s).
# I0000 00:00:1738755030.564952   14816 random_forest.cc:812] Training of tree  1/50 (tree index:4) done accuracy:1 logloss:0
# I0000 00:00:1738755033.468088   14819 random_forest.cc:812] Training of tree  11/50 (tree index:7) done accuracy:0.999997 logloss:4.53335e-05
# I0000 00:00:1738755039.504534   14816 random_forest.cc:812] Training of tree  21/50 (tree index:16) done accuracy:1 logloss:9.47273e-06
# I0000 00:00:1738755043.267682   14819 random_forest.cc:812] Training of tree  31/50 (tree index:26) done accuracy:1 logloss:9.54923e-06
# I0000 00:00:1738755047.733723   14826 random_forest.cc:812] Training of tree  41/50 (tree index:39) done accuracy:1 logloss:1.11901e-05
# I0000 00:00:1738755049.647607   14823 random_forest.cc:812] Training of tree  50/50 (tree index:48) done accuracy:1 logloss:1.08307e-05
# I0000 00:00:1738755049.648366   14812 random_forest.cc:892] Final OOB metrics: accuracy:1 logloss:1.08307e-05
# I0000 00:00:1738755049.665571   14812 kernel.cc:920] Export model in log directory: /tmp/tmpmw58877v with prefix af857f83775d4abc
# I0000 00:00:1738755049.668898   14812 kernel.cc:938] Save model in resources
# I0000 00:00:1738755049.670731    5704 abstract_model.cc:833] Model self evaluation:
# Number of predictions (without weights): 952656
# Number of predictions (with weights): 952656
# Task: CLASSIFICATION
# Label: __LABEL
#
# Accuracy: 1  CI95[W][0.999997 1]
# LogLoss: : 1.08307e-05
# ErrorRate: : 0
#
# Default Accuracy: : 0.926876
# Default LogLoss: : 0.261646
# Default ErrorRate: : 0.073124
#
# Confusion Table:
# truth\prediction
#         1      2
# 1  882994      0
# 2       0  69662
# Total: 952656
#
#
# 2025-02-05 12:30:49.675761: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1234] Loading model from path /tmp/tmpmw58877v/model/ with prefix af857f83775d4abc
# I0000 00:00:1738755049.679274    5704 decision_forest.cc:761] Model loaded with 50 root(s), 1930 node(s), and 19 input feature(s).
# I0000 00:00:1738755049.679295    5704 abstract_model.cc:1323] Engine "RandomForestOptPred" built
# 2025-02-05 12:30:49.679307: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1062] Use fast generic engine
# Training complete
# Loading NF-UNSW-NB15 testset
# (324624, 33)
# Loading complete
# Evaluating model trained on WUSTL-IIOT trainset on NF-UNSW-NB15 testset
# 635/635 [==============================] - 5s 7ms/step
# Evaluation complete
# Results for:...
# Model trained on WUSTL-IIOT and evaluated on NF-UNSW-NB15
# [[ 34042 276212]
#  [  2103  12267]]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.11      0.20    310254
#          1.0       0.04      0.85      0.08     14370
#
#     accuracy                           0.14    324624
#    macro avg       0.49      0.48      0.14    324624
# weighted avg       0.90      0.14      0.19    324624
#
# ---
# Loading NF-CSE-CIC-IDS2018 testset
# (1678480, 33)
# Loading complete
# Evaluating model trained on WUSTL-IIOT trainset on NF-CSE-CIC-IDS2018 testset
# 3279/3279 [==============================] - 26s 8ms/step
# Evaluation complete
# Results for:...
# Model trained on WUSTL-IIOT and evaluated on NF-CSE-CIC-IDS2018
# [[994344 480877]
#  [102195 101064]]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.67      0.77   1475221
#          1.0       0.17      0.50      0.26    203259
#
#     accuracy                           0.65   1678480
#    macro avg       0.54      0.59      0.52   1678480
# weighted avg       0.82      0.65      0.71   1678480
#
# ---
# Loading NF-BoT-IoT testset
# (120020, 33)
# Loading complete
# Evaluating model trained on WUSTL-IIOT trainset on NF-BoT-IoT testset
# 235/235 [==============================] - 2s 7ms/step
# Evaluation complete
# Results for:...
# Model trained on WUSTL-IIOT and evaluated on NF-BoT-IoT
# [[  400  2400]
#  [25846 91374]]
#               precision    recall  f1-score   support
#
#          0.0       0.02      0.14      0.03      2800
#          1.0       0.97      0.78      0.87    117220
#
#     accuracy                           0.76    120020
#    macro avg       0.49      0.46      0.45    120020
# weighted avg       0.95      0.76      0.85    120020
#
# ---
# Loading NF-ToN-IoT testset
# (275855, 33)
# Loading complete
# Evaluating model trained on WUSTL-IIOT trainset on NF-ToN-IoT testset
# 539/539 [==============================] - 4s 8ms/step
# Evaluation complete
# Results for:...
# Model trained on WUSTL-IIOT and evaluated on NF-ToN-IoT
# [[ 22607  31317]
#  [221756    175]]
#               precision    recall  f1-score   support
#
#          0.0       0.09      0.42      0.15     53924
#          1.0       0.01      0.00      0.00    221931
#
#     accuracy                           0.08    275855
#    macro avg       0.05      0.21      0.08    275855
# weighted avg       0.02      0.08      0.03    275855
#
# ---
# Loading X-IIoTiD testset
# (164018, 33)
# Loading complete
# Evaluating model trained on WUSTL-IIOT trainset on X-IIoTiD testset
# 321/321 [==============================] - 2s 8ms/step
# Evaluation complete
# Results for:...
# Model trained on WUSTL-IIOT and evaluated on X-IIoTiD
# [[43418 40652]
#  [21357 58591]]
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.52      0.58     84070
#          1.0       0.59      0.73      0.65     79948
#
#     accuracy                           0.62    164018
#    macro avg       0.63      0.62      0.62    164018
# weighted avg       0.63      0.62      0.62    164018
#
# ---
# Loading WUSTL-IIOT testset
# (238165, 33)
# Loading complete
# Evaluating model trained on WUSTL-IIOT trainset on WUSTL-IIOT testset
# 466/466 [==============================] - 4s 7ms/step
# Evaluation complete
# Results for:...
# Model trained on WUSTL-IIOT and evaluated on WUSTL-IIOT
# [[220811      0]
#  [     0  17354]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00    220811
#          1.0       1.00      1.00      1.00     17354
#
#     accuracy                           1.00    238165
#    macro avg       1.00      1.00      1.00    238165
# weighted avg       1.00      1.00      1.00    238165
#
# ---
# Cleanup complete
# ---+++---
# CPU times: user 1h 34min 24s, sys: 2min 53s, total: 1h 37min 18s
# Wall time: 16min 18s

# %%
result_df.to_csv(cwd+"/results/"+model_name+"_results.csv",index=False)
