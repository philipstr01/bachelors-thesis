# %%
#Imports
import io
import os
import gc
import copy
import math
import ctypes
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_fscore_support, accuracy_score, balanced_accuracy_score, matthews_corrcoef
from sklearn import metrics

import tensorflow as tf
from tensorflow.keras import Input, Model, layers, losses, optimizers, callbacks

#Notebook settings
default_max_columns = None
default_max_rows = 10
pd.set_option('display.max_columns', default_max_columns)
pd.set_option('display.max_rows', default_max_rows)

model_name = "NEURAL_NETWORK"
label_column = "Label"
batch_size = 512
num_datasets = 6
cwd = os.getcwd()

# %%
#Utility functions
def split_xy(df, colname):
    y_cols = [c for c in df.columns if c.startswith(colname)]
    x_cols = np.setdiff1d(df.columns, y_cols)
    X = df[x_cols]
    Y = df[y_cols]
    return X, Y

# %%
# %%time
#Training and evaluating loop designed to work with memory constraints 

df_names = ['NF-UNSW-NB15', 'NF-CSE-CIC-IDS2018', 'NF-BoT-IoT', 'NF-ToN-IoT', 'X-IIoTiD', 'WUSTL-IIOT']
result_df = pd.DataFrame(columns=("TRAIN_DATASET", "EVAL_DATASET", "METRIC", "VAlUE", "LABEL", "MODEL"))

for i in range(num_datasets):

    #Model definiton
    #Deep Neural Network Binary Classifier with sigmoid activiation and 4 layers
    def make_nn_model(input_shape=[32], n_out=2):
        inx = Input(input_shape)
        x = layers.Dense(64, activation=tf.keras.activations.sigmoid)(inx)
        x = layers.Dense(32, activation=tf.keras.activations.sigmoid)(x)
        x = layers.Dense(n_out,activation=tf.keras.activations.sigmoid)(x)
        return Model(inx, x)
    
    loss = losses.BinaryCrossentropy()
    opt = optimizers.Adam(learning_rate=5e-3)
    nn_modell = make_nn_model()
    nn_modell.compile(loss=loss, optimizer=opt, metrics=['accuracy'])

    #Load training and validation data
    print("Loading "+df_names[i]+" trainingset")
    df_train = pd.read_csv(cwd+"/normalized_datasets/"+df_names[i]+"_n_Trainset.csv", dtype=float)
    print(df_train.shape)
    xtrain, ytrain = split_xy(df_train, label_column) 
    ytrain = pd.get_dummies(ytrain, columns=[label_column], dtype = "float") #Split Labels per Class
    del df_train
    trainset = tf.data.Dataset.from_tensor_slices((xtrain, ytrain)).batch(batch_size)
    del xtrain, ytrain
    
    df_val = pd.read_csv(cwd+"/normalized_datasets/"+df_names[i]+"_n_Valset.csv", dtype=float)
    xval, yval = split_xy(df_val, label_column) 
    yval = pd.get_dummies(yval, columns=[label_column], dtype = "float") #Split Labels per Class
    del df_val
    valset = tf.data.Dataset.from_tensor_slices((xval, yval)).batch(batch_size)
    del xval, yval
    
    gc.collect()
    print("Loading complete")
    
    #Train
    print("Training on "+df_names[i]+" trainingset")
    hist = nn_modell.fit(trainset,validation_data = valset, epochs = 50, verbose = 1)
    del trainset, valset
    gc.collect
    print("Training complete")
    
    #Evaluation
    for j in range(num_datasets):

        print("Loading "+df_names[j]+" testset "+str(j))
        #Load test data
        df_test = pd.read_csv(cwd+"/normalized_datasets/"+df_names[j]+"_n_Testset.csv", dtype=float)
        print(df_test.shape)
        xtest, ytest = split_xy(df_test, label_column)
        del df_test
        print("Loading complete")

        #Predict
        print("Evaluating model trained on "+df_names[i]+" trainset on "+df_names[j]+" testset")
        ypred = pd.DataFrame(nn_modell.predict(xtest), columns=["Label_0","Label_1"])
        del xtest
        ypred["Label"] = ypred[["Label_0", "Label_1"]].idxmax(axis=1)
        ypred["Label"] = ypred["Label"].apply(lambda x: 0 if x == "Label_0" else 1).astype("float32")
        ypred = ypred["Label"].to_numpy() 
      
        print("Evaluation complete")
        #Results
        print("Results for:...")
        print("Model trained on "+df_names[i]+" and evaluated on "+df_names[j])
        print(confusion_matrix(ytest, ypred))
        print(classification_report(ytest, ypred))
        precision, recall, f1_score, support = precision_recall_fscore_support(ytest,ypred, zero_division = 0.0)
        accuracy = accuracy_score(ytest, ypred)
        balanced_accuracy = balanced_accuracy_score(ytest, ypred)
        mcc = matthews_corrcoef(ytest, ypred)
        print("---")

        del ypred,ytest
        gc.collect

        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"ACCURACY", "VAlUE":accuracy, "LABEL":"BOTH", "MODEL":model_name}, index = [0])], ignore_index=True)
        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"BALANCED_ACCURACY", "VAlUE":balanced_accuracy, "LABEL":"BOTH", "MODEL":model_name}, index = [0])], ignore_index=True)
        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"MCC", "VAlUE":mcc, "LABEL":"BOTH", "MODEL":model_name}, index = [0])], ignore_index=True)
        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"PRECISION", "VAlUE":precision[0], "LABEL":"0", "MODEL":model_name}, index = [0])], ignore_index=True)
        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"PRECISION", "VAlUE":precision[1], "LABEL":"1", "MODEL":model_name}, index = [0])], ignore_index=True)   
        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"RECALL", "VAlUE":recall[0], "LABEL":"0", "MODEL":model_name}, index = [0])], ignore_index=True)
        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"RECALL", "VAlUE":recall[1], "LABEL":"1", "MODEL":model_name}, index = [0])], ignore_index=True)
        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"F1_SCORE", "VAlUE":f1_score[0], "LABEL":"0", "MODEL":model_name}, index = [0])], ignore_index=True)
        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"F1_SCORE", "VAlUE":f1_score[1], "LABEL":"1", "MODEL":model_name}, index = [0])], ignore_index=True)
        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"SUPPORT", "VAlUE":support[0], "LABEL":"0", "MODEL":model_name}, index = [0])], ignore_index=True)
        result_df = pd.concat([result_df,pd.DataFrame({"TRAIN_DATASET":df_names[i], "EVAL_DATASET":df_names[j], "METRIC":"SUPPORT", "VAlUE":support[1], "LABEL":"1", "MODEL":model_name}, index = [0])], ignore_index=True)
        
    del nn_modell
    gc.collect
    libc = ctypes.CDLL("libc.so.6") # clearing cache 
    libc.malloc_trim(0)

    print("Cleanup complete")
    print("---+++---")
# Out:
# Loading NF-UNSW-NB15 trainingset
# (1168644, 33)
# Loading complete
# Training on NF-UNSW-NB15 trainingset
# Epoch 1/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9626 - loss: 0.0917 - val_accuracy: 0.9673 - val_loss: 0.0446
# Epoch 2/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9755 - loss: 0.0412 - val_accuracy: 0.9648 - val_loss: 0.0454
# Epoch 3/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9759 - loss: 0.0407 - val_accuracy: 0.9663 - val_loss: 0.0450
# Epoch 4/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9762 - loss: 0.0404 - val_accuracy: 0.9674 - val_loss: 0.0445
# Epoch 5/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9765 - loss: 0.0401 - val_accuracy: 0.9679 - val_loss: 0.0442
# Epoch 6/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9768 - loss: 0.0397 - val_accuracy: 0.9693 - val_loss: 0.0435
# Epoch 7/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9773 - loss: 0.0394 - val_accuracy: 0.9712 - val_loss: 0.0427
# Epoch 8/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9777 - loss: 0.0391 - val_accuracy: 0.9726 - val_loss: 0.0420
# Epoch 9/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9779 - loss: 0.0389 - val_accuracy: 0.9732 - val_loss: 0.0415
# Epoch 10/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9780 - loss: 0.0387 - val_accuracy: 0.9735 - val_loss: 0.0413
# Epoch 11/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9781 - loss: 0.0385 - val_accuracy: 0.9738 - val_loss: 0.0412
# Epoch 12/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9782 - loss: 0.0383 - val_accuracy: 0.9738 - val_loss: 0.0411
# Epoch 13/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9783 - loss: 0.0382 - val_accuracy: 0.9736 - val_loss: 0.0411
# Epoch 14/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9784 - loss: 0.0380 - val_accuracy: 0.9735 - val_loss: 0.0411
# Epoch 15/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9785 - loss: 0.0378 - val_accuracy: 0.9734 - val_loss: 0.0411
# Epoch 16/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9786 - loss: 0.0377 - val_accuracy: 0.9733 - val_loss: 0.0411
# Epoch 17/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9788 - loss: 0.0375 - val_accuracy: 0.9733 - val_loss: 0.0410
# Epoch 18/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9788 - loss: 0.0373 - val_accuracy: 0.9734 - val_loss: 0.0409
# Epoch 19/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9788 - loss: 0.0372 - val_accuracy: 0.9735 - val_loss: 0.0408
# Epoch 20/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9789 - loss: 0.0370 - val_accuracy: 0.9736 - val_loss: 0.0406
# Epoch 21/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9789 - loss: 0.0369 - val_accuracy: 0.9738 - val_loss: 0.0403
# Epoch 22/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9789 - loss: 0.0368 - val_accuracy: 0.9740 - val_loss: 0.0401
# Epoch 23/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9790 - loss: 0.0366 - val_accuracy: 0.9743 - val_loss: 0.0397
# Epoch 24/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9792 - loss: 0.0364 - val_accuracy: 0.9745 - val_loss: 0.0394
# Epoch 25/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9792 - loss: 0.0363 - val_accuracy: 0.9747 - val_loss: 0.0391
# Epoch 26/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9792 - loss: 0.0362 - val_accuracy: 0.9749 - val_loss: 0.0389
# Epoch 27/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9793 - loss: 0.0361 - val_accuracy: 0.9751 - val_loss: 0.0387
# Epoch 28/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9794 - loss: 0.0360 - val_accuracy: 0.9752 - val_loss: 0.0385
# Epoch 29/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9794 - loss: 0.0359 - val_accuracy: 0.9753 - val_loss: 0.0384
# Epoch 30/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9794 - loss: 0.0358 - val_accuracy: 0.9754 - val_loss: 0.0383
# Epoch 31/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9794 - loss: 0.0358 - val_accuracy: 0.9756 - val_loss: 0.0382
# Epoch 32/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9795 - loss: 0.0357 - val_accuracy: 0.9756 - val_loss: 0.0381
# Epoch 33/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9795 - loss: 0.0357 - val_accuracy: 0.9757 - val_loss: 0.0380
# Epoch 34/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9795 - loss: 0.0357 - val_accuracy: 0.9758 - val_loss: 0.0379
# Epoch 35/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9795 - loss: 0.0356 - val_accuracy: 0.9759 - val_loss: 0.0378
# Epoch 36/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9795 - loss: 0.0356 - val_accuracy: 0.9760 - val_loss: 0.0377
# Epoch 37/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9796 - loss: 0.0355 - val_accuracy: 0.9763 - val_loss: 0.0376
# Epoch 38/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9796 - loss: 0.0355 - val_accuracy: 0.9766 - val_loss: 0.0374
# Epoch 39/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9796 - loss: 0.0354 - val_accuracy: 0.9769 - val_loss: 0.0373
# Epoch 40/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9796 - loss: 0.0354 - val_accuracy: 0.9771 - val_loss: 0.0371
# Epoch 41/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9796 - loss: 0.0353 - val_accuracy: 0.9773 - val_loss: 0.0370
# Epoch 42/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9796 - loss: 0.0353 - val_accuracy: 0.9774 - val_loss: 0.0369
# Epoch 43/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9796 - loss: 0.0352 - val_accuracy: 0.9774 - val_loss: 0.0367
# Epoch 44/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9797 - loss: 0.0351 - val_accuracy: 0.9776 - val_loss: 0.0366
# Epoch 45/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9797 - loss: 0.0351 - val_accuracy: 0.9778 - val_loss: 0.0365
# Epoch 46/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9797 - loss: 0.0350 - val_accuracy: 0.9779 - val_loss: 0.0364
# Epoch 47/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9798 - loss: 0.0350 - val_accuracy: 0.9780 - val_loss: 0.0363
# Epoch 48/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9798 - loss: 0.0349 - val_accuracy: 0.9780 - val_loss: 0.0362
# Epoch 49/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9799 - loss: 0.0349 - val_accuracy: 0.9782 - val_loss: 0.0361
# Epoch 50/50
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9799 - loss: 0.0348 - val_accuracy: 0.9785 - val_loss: 0.0360
# Training complete
# Loading NF-UNSW-NB15 testset 0
# (324624, 33)
# Loading complete
# Evaluating model trained on NF-UNSW-NB15 trainset on NF-UNSW-NB15 testset
# 10145/10145 ━━━━━━━━━━━━━━━━━━━━ 6s 599us/step
# Evaluation complete
# Results for:...
# Model trained on NF-UNSW-NB15 and evaluated on NF-UNSW-NB15
# [[306758   3454]
#  [  3270  11142]]
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99    310212
#          1.0       0.76      0.77      0.77     14412
#
#     accuracy                           0.98    324624
#    macro avg       0.88      0.88      0.88    324624
# weighted avg       0.98      0.98      0.98    324624
#
# ---
# Loading NF-CSE-CIC-IDS2018 testset 1
# <timed exec>:83: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# (1678480, 33)
# Loading complete
# Evaluating model trained on NF-UNSW-NB15 trainset on NF-CSE-CIC-IDS2018 testset
# 52453/52453 ━━━━━━━━━━━━━━━━━━━━ 32s 609us/step
# Evaluation complete
# Results for:...
# Model trained on NF-UNSW-NB15 and evaluated on NF-CSE-CIC-IDS2018
# [[1449607   24932]
#  [ 203941       0]]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.98      0.93   1474539
#          1.0       0.00      0.00      0.00    203941
#
#     accuracy                           0.86   1678480
#    macro avg       0.44      0.49      0.46   1678480
# weighted avg       0.77      0.86      0.81   1678480
#
# ---
# Loading NF-BoT-IoT testset 2
# (120020, 33)
# Loading complete
# Evaluating model trained on NF-UNSW-NB15 trainset on NF-BoT-IoT testset
# 3751/3751 ━━━━━━━━━━━━━━━━━━━━ 3s 704us/step
# Evaluation complete
# Results for:...
# Model trained on NF-UNSW-NB15 and evaluated on NF-BoT-IoT
# [[  2716     62]
#  [117197     45]]
#               precision    recall  f1-score   support
#
#          0.0       0.02      0.98      0.04      2778
#          1.0       0.42      0.00      0.00    117242
#
#     accuracy                           0.02    120020
#    macro avg       0.22      0.49      0.02    120020
# weighted avg       0.41      0.02      0.00    120020
#
# ---
# Loading NF-ToN-IoT testset 3
# (275855, 33)
# Loading complete
# Evaluating model trained on NF-UNSW-NB15 trainset on NF-ToN-IoT testset
# 8621/8621 ━━━━━━━━━━━━━━━━━━━━ 5s 598us/step
# Evaluation complete
# Results for:...
# Model trained on NF-UNSW-NB15 and evaluated on NF-ToN-IoT
# [[ 53560     94]
#  [222201      0]]
#               precision    recall  f1-score   support
#
#          0.0       0.19      1.00      0.33     53654
#          1.0       0.00      0.00      0.00    222201
#
#     accuracy                           0.19    275855
#    macro avg       0.10      0.50      0.16    275855
# weighted avg       0.04      0.19      0.06    275855
#
# ---
# Loading X-IIoTiD testset 4
# (164018, 33)
# Loading complete
# Evaluating model trained on NF-UNSW-NB15 trainset on X-IIoTiD testset
# 5126/5126 ━━━━━━━━━━━━━━━━━━━━ 4s 705us/step
# Evaluation complete
# Results for:...
# Model trained on NF-UNSW-NB15 and evaluated on X-IIoTiD
# [[37231 47132]
#  [70840  8815]]
#               precision    recall  f1-score   support
#
#          0.0       0.34      0.44      0.39     84363
#          1.0       0.16      0.11      0.13     79655
#
#     accuracy                           0.28    164018
#    macro avg       0.25      0.28      0.26    164018
# weighted avg       0.25      0.28      0.26    164018
#
# ---
# Loading WUSTL-IIOT testset 5
# (238165, 33)
# Loading complete
# Evaluating model trained on NF-UNSW-NB15 trainset on WUSTL-IIOT testset
# 7443/7443 ━━━━━━━━━━━━━━━━━━━━ 5s 614us/step
# Evaluation complete
# Results for:...
# Model trained on NF-UNSW-NB15 and evaluated on WUSTL-IIOT
# [[220915      0]
#  [ 17250      0]]
# /home/philip/anaconda3/envs/keras2/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/philip/anaconda3/envs/keras2/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/philip/anaconda3/envs/keras2/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.96    220915
#          1.0       0.00      0.00      0.00     17250
#
#     accuracy                           0.93    238165
#    macro avg       0.46      0.50      0.48    238165
# weighted avg       0.86      0.93      0.89    238165
#
# ---
# Cleanup complete
# ---+++---
# Loading NF-CSE-CIC-IDS2018 trainingset
# (6042527, 33)
# 2025-01-11 17:00:55.803830: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1546886912 exceeds 10% of free system memory.
# Loading complete
# Training on NF-CSE-CIC-IDS2018 trainingset
# Epoch 1/50
# 2025-01-11 17:00:58.509408: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1546886912 exceeds 10% of free system memory.
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 34s 3ms/step - accuracy: 0.9857 - loss: 0.0590 - val_accuracy: 0.9920 - val_loss: 0.0345
# Epoch 2/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9920 - loss: 0.0333 - val_accuracy: 0.9924 - val_loss: 0.0315
# Epoch 3/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 33s 3ms/step - accuracy: 0.9924 - loss: 0.0305 - val_accuracy: 0.9929 - val_loss: 0.0293
# Epoch 4/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 33s 3ms/step - accuracy: 0.9926 - loss: 0.0277 - val_accuracy: 0.9927 - val_loss: 0.0246
# Epoch 5/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 33s 3ms/step - accuracy: 0.9928 - loss: 0.0237 - val_accuracy: 0.9927 - val_loss: 0.0227
# Epoch 6/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9928 - loss: 0.0213 - val_accuracy: 0.9928 - val_loss: 0.0209
# Epoch 7/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9928 - loss: 0.0200 - val_accuracy: 0.9927 - val_loss: 0.0201
# Epoch 8/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9929 - loss: 0.0192 - val_accuracy: 0.9929 - val_loss: 0.0195
# Epoch 9/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 33s 3ms/step - accuracy: 0.9929 - loss: 0.0186 - val_accuracy: 0.9929 - val_loss: 0.0190
# Epoch 10/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9930 - loss: 0.0181 - val_accuracy: 0.9930 - val_loss: 0.0185
# Epoch 11/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9930 - loss: 0.0178 - val_accuracy: 0.9929 - val_loss: 0.0180
# Epoch 12/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 33s 3ms/step - accuracy: 0.9930 - loss: 0.0175 - val_accuracy: 0.9930 - val_loss: 0.0176
# Epoch 13/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9930 - loss: 0.0172 - val_accuracy: 0.9930 - val_loss: 0.0172
# Epoch 14/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9930 - loss: 0.0170 - val_accuracy: 0.9930 - val_loss: 0.0169
# Epoch 15/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9930 - loss: 0.0168 - val_accuracy: 0.9930 - val_loss: 0.0166
# Epoch 16/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9930 - loss: 0.0167 - val_accuracy: 0.9930 - val_loss: 0.0163
# Epoch 17/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 33s 3ms/step - accuracy: 0.9930 - loss: 0.0165 - val_accuracy: 0.9930 - val_loss: 0.0160
# Epoch 18/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9931 - loss: 0.0164 - val_accuracy: 0.9931 - val_loss: 0.0157
# Epoch 19/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 31s 3ms/step - accuracy: 0.9931 - loss: 0.0162 - val_accuracy: 0.9932 - val_loss: 0.0155
# Epoch 20/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 31s 3ms/step - accuracy: 0.9931 - loss: 0.0161 - val_accuracy: 0.9933 - val_loss: 0.0153
# Epoch 21/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9931 - loss: 0.0160 - val_accuracy: 0.9933 - val_loss: 0.0152
# Epoch 22/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9931 - loss: 0.0159 - val_accuracy: 0.9934 - val_loss: 0.0151
# Epoch 23/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 31s 3ms/step - accuracy: 0.9931 - loss: 0.0158 - val_accuracy: 0.9934 - val_loss: 0.0150
# Epoch 24/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9931 - loss: 0.0157 - val_accuracy: 0.9934 - val_loss: 0.0149
# Epoch 25/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 31s 3ms/step - accuracy: 0.9932 - loss: 0.0156 - val_accuracy: 0.9935 - val_loss: 0.0149
# Epoch 26/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9932 - loss: 0.0155 - val_accuracy: 0.9935 - val_loss: 0.0148
# Epoch 27/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9932 - loss: 0.0154 - val_accuracy: 0.9935 - val_loss: 0.0148
# Epoch 28/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9932 - loss: 0.0153 - val_accuracy: 0.9935 - val_loss: 0.0147
# Epoch 29/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9932 - loss: 0.0153 - val_accuracy: 0.9935 - val_loss: 0.0146
# Epoch 30/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9932 - loss: 0.0152 - val_accuracy: 0.9935 - val_loss: 0.0146
# Epoch 31/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9932 - loss: 0.0151 - val_accuracy: 0.9935 - val_loss: 0.0145
# Epoch 32/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9932 - loss: 0.0150 - val_accuracy: 0.9935 - val_loss: 0.0144
# Epoch 33/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9932 - loss: 0.0149 - val_accuracy: 0.9935 - val_loss: 0.0144
# Epoch 34/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9932 - loss: 0.0148 - val_accuracy: 0.9935 - val_loss: 0.0143
# Epoch 35/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9932 - loss: 0.0148 - val_accuracy: 0.9935 - val_loss: 0.0142
# Epoch 36/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 31s 3ms/step - accuracy: 0.9932 - loss: 0.0147 - val_accuracy: 0.9935 - val_loss: 0.0142
# Epoch 37/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9932 - loss: 0.0146 - val_accuracy: 0.9935 - val_loss: 0.0141
# Epoch 38/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9932 - loss: 0.0146 - val_accuracy: 0.9935 - val_loss: 0.0140
# Epoch 39/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 31s 3ms/step - accuracy: 0.9932 - loss: 0.0145 - val_accuracy: 0.9935 - val_loss: 0.0139
# Epoch 40/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 33s 3ms/step - accuracy: 0.9932 - loss: 0.0144 - val_accuracy: 0.9935 - val_loss: 0.0139
# Epoch 41/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9932 - loss: 0.0144 - val_accuracy: 0.9935 - val_loss: 0.0138
# Epoch 42/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9933 - loss: 0.0143 - val_accuracy: 0.9936 - val_loss: 0.0137
# Epoch 43/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9933 - loss: 0.0143 - val_accuracy: 0.9936 - val_loss: 0.0137
# Epoch 44/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9933 - loss: 0.0142 - val_accuracy: 0.9936 - val_loss: 0.0137
# Epoch 45/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9933 - loss: 0.0142 - val_accuracy: 0.9936 - val_loss: 0.0136
# Epoch 46/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9933 - loss: 0.0141 - val_accuracy: 0.9936 - val_loss: 0.0136
# Epoch 47/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9933 - loss: 0.0141 - val_accuracy: 0.9936 - val_loss: 0.0136
# Epoch 48/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9933 - loss: 0.0140 - val_accuracy: 0.9935 - val_loss: 0.0136
# Epoch 49/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9933 - loss: 0.0140 - val_accuracy: 0.9935 - val_loss: 0.0136
# Epoch 50/50
# 11802/11802 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - accuracy: 0.9933 - loss: 0.0139 - val_accuracy: 0.9935 - val_loss: 0.0136
# Training complete
# Loading NF-UNSW-NB15 testset 0
# (324624, 33)
# Loading complete
# Evaluating model trained on NF-CSE-CIC-IDS2018 trainset on NF-UNSW-NB15 testset
# 10145/10145 ━━━━━━━━━━━━━━━━━━━━ 7s 649us/step
# Evaluation complete
# Results for:...
# Model trained on NF-CSE-CIC-IDS2018 and evaluated on NF-UNSW-NB15
# [[271642  38570]
#  [ 14313     99]]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.88      0.91    310212
#          1.0       0.00      0.01      0.00     14412
#
#     accuracy                           0.84    324624
#    macro avg       0.48      0.44      0.46    324624
# weighted avg       0.91      0.84      0.87    324624
#
# ---
# Loading NF-CSE-CIC-IDS2018 testset 1
# (1678480, 33)
# Loading complete
# Evaluating model trained on NF-CSE-CIC-IDS2018 trainset on NF-CSE-CIC-IDS2018 testset
# 52453/52453 ━━━━━━━━━━━━━━━━━━━━ 33s 622us/step
# Evaluation complete
# Results for:...
# Model trained on NF-CSE-CIC-IDS2018 and evaluated on NF-CSE-CIC-IDS2018
# [[1472950    1589]
#  [   9186  194755]]
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00   1474539
#          1.0       0.99      0.95      0.97    203941
#
#     accuracy                           0.99   1678480
#    macro avg       0.99      0.98      0.98   1678480
# weighted avg       0.99      0.99      0.99   1678480
#
# ---
# Loading NF-BoT-IoT testset 2
# (120020, 33)
# Loading complete
# Evaluating model trained on NF-CSE-CIC-IDS2018 trainset on NF-BoT-IoT testset
# 3751/3751 ━━━━━━━━━━━━━━━━━━━━ 2s 622us/step
# Evaluation complete
# Results for:...
# Model trained on NF-CSE-CIC-IDS2018 and evaluated on NF-BoT-IoT
# [[ 1825   953]
#  [60114 57128]]
#               precision    recall  f1-score   support
#
#          0.0       0.03      0.66      0.06      2778
#          1.0       0.98      0.49      0.65    117242
#
#     accuracy                           0.49    120020
#    macro avg       0.51      0.57      0.35    120020
# weighted avg       0.96      0.49      0.64    120020
#
# ---
# Loading NF-ToN-IoT testset 3
# (275855, 33)
# Loading complete
# Evaluating model trained on NF-CSE-CIC-IDS2018 trainset on NF-ToN-IoT testset
# 8621/8621 ━━━━━━━━━━━━━━━━━━━━ 6s 646us/step
# Evaluation complete
# Results for:...
# Model trained on NF-CSE-CIC-IDS2018 and evaluated on NF-ToN-IoT
# [[ 53652      2]
#  [222201      0]]
#               precision    recall  f1-score   support
#
#          0.0       0.19      1.00      0.33     53654
#          1.0       0.00      0.00      0.00    222201
#
#     accuracy                           0.19    275855
#    macro avg       0.10      0.50      0.16    275855
# weighted avg       0.04      0.19      0.06    275855
#
# ---
# Loading X-IIoTiD testset 4
# (164018, 33)
# Loading complete
# Evaluating model trained on NF-CSE-CIC-IDS2018 trainset on X-IIoTiD testset
# 5126/5126 ━━━━━━━━━━━━━━━━━━━━ 3s 644us/step
# Evaluation complete
# Results for:...
# Model trained on NF-CSE-CIC-IDS2018 and evaluated on X-IIoTiD
# [[84343    20]
#  [79652     3]]
#               precision    recall  f1-score   support
#
#          0.0       0.51      1.00      0.68     84363
#          1.0       0.13      0.00      0.00     79655
#
#     accuracy                           0.51    164018
#    macro avg       0.32      0.50      0.34    164018
# weighted avg       0.33      0.51      0.35    164018
#
# ---
# Loading WUSTL-IIOT testset 5
# (238165, 33)
# Loading complete
# Evaluating model trained on NF-CSE-CIC-IDS2018 trainset on WUSTL-IIOT testset
# 7443/7443 ━━━━━━━━━━━━━━━━━━━━ 5s 657us/step
# Evaluation complete
# Results for:...
# Model trained on NF-CSE-CIC-IDS2018 and evaluated on WUSTL-IIOT
# [[220915      0]
#  [ 17225     25]]
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.96    220915
#          1.0       1.00      0.00      0.00     17250
#
#     accuracy                           0.93    238165
#    macro avg       0.96      0.50      0.48    238165
# weighted avg       0.93      0.93      0.89    238165
#
# ---
# Cleanup complete
# ---+++---
# Loading NF-BoT-IoT trainingset
# (432072, 33)
# Loading complete
# Training on NF-BoT-IoT trainingset
# Epoch 1/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9435 - loss: 0.1553 - val_accuracy: 0.9857 - val_loss: 0.0517
# Epoch 2/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9863 - loss: 0.0507 - val_accuracy: 0.9871 - val_loss: 0.0477
# Epoch 3/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9868 - loss: 0.0481 - val_accuracy: 0.9874 - val_loss: 0.0471
# Epoch 4/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9871 - loss: 0.0475 - val_accuracy: 0.9875 - val_loss: 0.0467
# Epoch 5/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9872 - loss: 0.0471 - val_accuracy: 0.9875 - val_loss: 0.0463
# Epoch 6/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9873 - loss: 0.0467 - val_accuracy: 0.9875 - val_loss: 0.0459
# Epoch 7/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9873 - loss: 0.0465 - val_accuracy: 0.9875 - val_loss: 0.0456
# Epoch 8/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9873 - loss: 0.0462 - val_accuracy: 0.9875 - val_loss: 0.0454
# Epoch 9/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9873 - loss: 0.0459 - val_accuracy: 0.9876 - val_loss: 0.0452
# Epoch 10/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9873 - loss: 0.0457 - val_accuracy: 0.9876 - val_loss: 0.0450
# Epoch 11/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9873 - loss: 0.0455 - val_accuracy: 0.9876 - val_loss: 0.0448
# Epoch 12/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9873 - loss: 0.0452 - val_accuracy: 0.9876 - val_loss: 0.0446
# Epoch 13/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9873 - loss: 0.0450 - val_accuracy: 0.9876 - val_loss: 0.0444
# Epoch 14/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9874 - loss: 0.0448 - val_accuracy: 0.9876 - val_loss: 0.0441
# Epoch 15/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9874 - loss: 0.0446 - val_accuracy: 0.9877 - val_loss: 0.0439
# Epoch 16/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9875 - loss: 0.0444 - val_accuracy: 0.9878 - val_loss: 0.0437
# Epoch 17/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9875 - loss: 0.0442 - val_accuracy: 0.9878 - val_loss: 0.0435
# Epoch 18/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9875 - loss: 0.0439 - val_accuracy: 0.9879 - val_loss: 0.0433
# Epoch 19/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9875 - loss: 0.0437 - val_accuracy: 0.9879 - val_loss: 0.0432
# Epoch 20/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9875 - loss: 0.0435 - val_accuracy: 0.9879 - val_loss: 0.0430
# Epoch 21/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9875 - loss: 0.0432 - val_accuracy: 0.9879 - val_loss: 0.0426
# Epoch 22/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9875 - loss: 0.0429 - val_accuracy: 0.9879 - val_loss: 0.0422
# Epoch 23/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9875 - loss: 0.0425 - val_accuracy: 0.9879 - val_loss: 0.0417
# Epoch 24/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9875 - loss: 0.0419 - val_accuracy: 0.9879 - val_loss: 0.0410
# Epoch 25/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9876 - loss: 0.0410 - val_accuracy: 0.9879 - val_loss: 0.0399
# Epoch 26/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9876 - loss: 0.0398 - val_accuracy: 0.9879 - val_loss: 0.0390
# Epoch 27/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9876 - loss: 0.0389 - val_accuracy: 0.9879 - val_loss: 0.0385
# Epoch 28/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9876 - loss: 0.0383 - val_accuracy: 0.9879 - val_loss: 0.0382
# Epoch 29/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9876 - loss: 0.0379 - val_accuracy: 0.9879 - val_loss: 0.0379
# Epoch 30/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9876 - loss: 0.0376 - val_accuracy: 0.9879 - val_loss: 0.0377
# Epoch 31/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9876 - loss: 0.0373 - val_accuracy: 0.9879 - val_loss: 0.0375
# Epoch 32/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9876 - loss: 0.0371 - val_accuracy: 0.9879 - val_loss: 0.0373
# Epoch 33/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9876 - loss: 0.0369 - val_accuracy: 0.9879 - val_loss: 0.0372
# Epoch 34/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9876 - loss: 0.0367 - val_accuracy: 0.9879 - val_loss: 0.0369
# Epoch 35/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9876 - loss: 0.0365 - val_accuracy: 0.9879 - val_loss: 0.0367
# Epoch 36/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9876 - loss: 0.0363 - val_accuracy: 0.9879 - val_loss: 0.0365
# Epoch 37/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9876 - loss: 0.0361 - val_accuracy: 0.9879 - val_loss: 0.0363
# Epoch 38/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9876 - loss: 0.0359 - val_accuracy: 0.9879 - val_loss: 0.0360
# Epoch 39/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9876 - loss: 0.0357 - val_accuracy: 0.9879 - val_loss: 0.0358
# Epoch 40/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9877 - loss: 0.0356 - val_accuracy: 0.9879 - val_loss: 0.0356
# Epoch 41/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9877 - loss: 0.0353 - val_accuracy: 0.9879 - val_loss: 0.0354
# Epoch 42/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9877 - loss: 0.0352 - val_accuracy: 0.9879 - val_loss: 0.0352
# Epoch 43/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9878 - loss: 0.0350 - val_accuracy: 0.9879 - val_loss: 0.0351
# Epoch 44/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9878 - loss: 0.0349 - val_accuracy: 0.9879 - val_loss: 0.0350
# Epoch 45/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9879 - loss: 0.0347 - val_accuracy: 0.9879 - val_loss: 0.0349
# Epoch 46/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9880 - loss: 0.0346 - val_accuracy: 0.9879 - val_loss: 0.0348
# Epoch 47/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9880 - loss: 0.0345 - val_accuracy: 0.9879 - val_loss: 0.0347
# Epoch 48/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9881 - loss: 0.0345 - val_accuracy: 0.9879 - val_loss: 0.0347
# Epoch 49/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9881 - loss: 0.0344 - val_accuracy: 0.9879 - val_loss: 0.0346
# Epoch 50/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9882 - loss: 0.0343 - val_accuracy: 0.9880 - val_loss: 0.0346
# Training complete
# Loading NF-UNSW-NB15 testset 0
# (324624, 33)
# Loading complete
# Evaluating model trained on NF-BoT-IoT trainset on NF-UNSW-NB15 testset
# 10145/10145 ━━━━━━━━━━━━━━━━━━━━ 6s 610us/step
# Evaluation complete
# Results for:...
# Model trained on NF-BoT-IoT and evaluated on NF-UNSW-NB15
# [[ 94184 216028]
#  [  3011  11401]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.30      0.46    310212
#          1.0       0.05      0.79      0.09     14412
#
#     accuracy                           0.33    324624
#    macro avg       0.51      0.55      0.28    324624
# weighted avg       0.93      0.33      0.45    324624
#
# ---
# Loading NF-CSE-CIC-IDS2018 testset 1
# (1678480, 33)
# Loading complete
# Evaluating model trained on NF-BoT-IoT trainset on NF-CSE-CIC-IDS2018 testset
# 52453/52453 ━━━━━━━━━━━━━━━━━━━━ 31s 588us/step
# Evaluation complete
# Results for:...
# Model trained on NF-BoT-IoT and evaluated on NF-CSE-CIC-IDS2018
# [[631341 843198]
#  [  9816 194125]]
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.43      0.60   1474539
#          1.0       0.19      0.95      0.31    203941
#
#     accuracy                           0.49   1678480
#    macro avg       0.59      0.69      0.45   1678480
# weighted avg       0.89      0.49      0.56   1678480
#
# ---
# Loading NF-BoT-IoT testset 2
# (120020, 33)
# Loading complete
# Evaluating model trained on NF-BoT-IoT trainset on NF-BoT-IoT testset
# 3751/3751 ━━━━━━━━━━━━━━━━━━━━ 2s 589us/step
# Evaluation complete
# Results for:...
# Model trained on NF-BoT-IoT and evaluated on NF-BoT-IoT
# [[  1326   1452]
#  [    14 117228]]
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.48      0.64      2778
#          1.0       0.99      1.00      0.99    117242
#
#     accuracy                           0.99    120020
#    macro avg       0.99      0.74      0.82    120020
# weighted avg       0.99      0.99      0.99    120020
#
# ---
# Loading NF-ToN-IoT testset 3
# (275855, 33)
# Loading complete
# Evaluating model trained on NF-BoT-IoT trainset on NF-ToN-IoT testset
# 8621/8621 ━━━━━━━━━━━━━━━━━━━━ 5s 608us/step
# Evaluation complete
# Results for:...
# Model trained on NF-BoT-IoT and evaluated on NF-ToN-IoT
# [[  9078  44576]
#  [ 12274 209927]]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.17      0.24     53654
#          1.0       0.82      0.94      0.88    222201
#
#     accuracy                           0.79    275855
#    macro avg       0.63      0.56      0.56    275855
# weighted avg       0.75      0.79      0.76    275855
#
# ---
# Loading X-IIoTiD testset 4
# (164018, 33)
# Loading complete
# Evaluating model trained on NF-BoT-IoT trainset on X-IIoTiD testset
# 5126/5126 ━━━━━━━━━━━━━━━━━━━━ 3s 574us/step
# Evaluation complete
# Results for:...
# Model trained on NF-BoT-IoT and evaluated on X-IIoTiD
# [[78138  6225]
#  [34038 45617]]
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.93      0.80     84363
#          1.0       0.88      0.57      0.69     79655
#
#     accuracy                           0.75    164018
#    macro avg       0.79      0.75      0.74    164018
# weighted avg       0.79      0.75      0.75    164018
#
# ---
# Loading WUSTL-IIOT testset 5
# (238165, 33)
# Loading complete
# Evaluating model trained on NF-BoT-IoT trainset on WUSTL-IIOT testset
# 7443/7443 ━━━━━━━━━━━━━━━━━━━━ 4s 586us/step
# Evaluation complete
# Results for:...
# Model trained on NF-BoT-IoT and evaluated on WUSTL-IIOT
# [[  1889 219026]
#  [  3823  13427]]
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.01      0.02    220915
#          1.0       0.06      0.78      0.11     17250
#
#     accuracy                           0.06    238165
#    macro avg       0.19      0.39      0.06    238165
# weighted avg       0.31      0.06      0.02    238165
#
# ---
# Cleanup complete
# ---+++---
# Loading NF-ToN-IoT trainingset
# (993077, 33)
# Loading complete
# Training on NF-ToN-IoT trainingset
# Epoch 1/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9677 - loss: 0.0830 - val_accuracy: 0.9986 - val_loss: 0.0084
# Epoch 2/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9988 - loss: 0.0076 - val_accuracy: 0.9988 - val_loss: 0.0078
# Epoch 3/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9989 - loss: 0.0070 - val_accuracy: 0.9990 - val_loss: 0.0072
# Epoch 4/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9991 - loss: 0.0065 - val_accuracy: 0.9991 - val_loss: 0.0063
# Epoch 5/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9992 - loss: 0.0055 - val_accuracy: 0.9993 - val_loss: 0.0047
# Epoch 6/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9994 - loss: 0.0045 - val_accuracy: 0.9993 - val_loss: 0.0047
# Epoch 7/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9994 - loss: 0.0043 - val_accuracy: 0.9993 - val_loss: 0.0047
# Epoch 8/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9994 - loss: 0.0042 - val_accuracy: 0.9994 - val_loss: 0.0046
# Epoch 9/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9994 - loss: 0.0041 - val_accuracy: 0.9994 - val_loss: 0.0044
# Epoch 10/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9994 - loss: 0.0040 - val_accuracy: 0.9994 - val_loss: 0.0043
# Epoch 11/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9994 - loss: 0.0038 - val_accuracy: 0.9994 - val_loss: 0.0040
# Epoch 12/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9994 - loss: 0.0036 - val_accuracy: 0.9994 - val_loss: 0.0036
# Epoch 13/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9994 - loss: 0.0034 - val_accuracy: 0.9994 - val_loss: 0.0032
# Epoch 14/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9994 - loss: 0.0031 - val_accuracy: 0.9994 - val_loss: 0.0027
# Epoch 15/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9994 - loss: 0.0029 - val_accuracy: 0.9994 - val_loss: 0.0024
# Epoch 16/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9995 - loss: 0.0027 - val_accuracy: 0.9994 - val_loss: 0.0021
# Epoch 17/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9995 - loss: 0.0026 - val_accuracy: 0.9995 - val_loss: 0.0019
# Epoch 18/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9995 - loss: 0.0024 - val_accuracy: 0.9996 - val_loss: 0.0017
# Epoch 19/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9995 - loss: 0.0022 - val_accuracy: 0.9997 - val_loss: 0.0016
# Epoch 20/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9995 - loss: 0.0021 - val_accuracy: 0.9997 - val_loss: 0.0015
# Epoch 21/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9996 - loss: 0.0020 - val_accuracy: 0.9998 - val_loss: 0.0014
# Epoch 22/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9996 - loss: 0.0019 - val_accuracy: 0.9998 - val_loss: 0.0014
# Epoch 23/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9996 - loss: 0.0018 - val_accuracy: 0.9998 - val_loss: 0.0013
# Epoch 24/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9996 - loss: 0.0018 - val_accuracy: 0.9997 - val_loss: 0.0013
# Epoch 25/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9996 - loss: 0.0017 - val_accuracy: 0.9997 - val_loss: 0.0012
# Epoch 26/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9996 - loss: 0.0017 - val_accuracy: 0.9998 - val_loss: 0.0012
# Epoch 27/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9996 - loss: 0.0016 - val_accuracy: 0.9998 - val_loss: 0.0012
# Epoch 28/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9996 - loss: 0.0016 - val_accuracy: 0.9998 - val_loss: 0.0011
# Epoch 29/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.9998 - val_loss: 0.0011
# Epoch 30/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.9998 - val_loss: 0.0011
# Epoch 31/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.9998 - val_loss: 0.0011
# Epoch 32/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.9998 - val_loss: 0.0011
# Epoch 33/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9996 - loss: 0.0014 - val_accuracy: 0.9998 - val_loss: 0.0010
# Epoch 34/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9996 - loss: 0.0014 - val_accuracy: 0.9998 - val_loss: 9.8979e-04
# Epoch 35/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9997 - loss: 0.0014 - val_accuracy: 0.9998 - val_loss: 9.6597e-04
# Epoch 36/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9997 - loss: 0.0013 - val_accuracy: 0.9998 - val_loss: 9.4644e-04
# Epoch 37/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9997 - loss: 0.0013 - val_accuracy: 0.9998 - val_loss: 9.2546e-04
# Epoch 38/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9997 - loss: 0.0013 - val_accuracy: 0.9998 - val_loss: 9.0526e-04
# Epoch 39/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9997 - loss: 0.0013 - val_accuracy: 0.9998 - val_loss: 8.9006e-04
# Epoch 40/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9997 - loss: 0.0012 - val_accuracy: 0.9998 - val_loss: 8.7707e-04
# Epoch 41/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9997 - loss: 0.0012 - val_accuracy: 0.9998 - val_loss: 8.6739e-04
# Epoch 42/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9997 - loss: 0.0012 - val_accuracy: 0.9998 - val_loss: 8.6252e-04
# Epoch 43/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9997 - loss: 0.0012 - val_accuracy: 0.9998 - val_loss: 8.5147e-04
# Epoch 44/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9997 - loss: 0.0012 - val_accuracy: 0.9998 - val_loss: 8.4808e-04
# Epoch 45/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9997 - loss: 0.0012 - val_accuracy: 0.9998 - val_loss: 8.4355e-04
# Epoch 46/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9997 - loss: 0.0012 - val_accuracy: 0.9998 - val_loss: 8.4098e-04
# Epoch 47/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9997 - loss: 0.0012 - val_accuracy: 0.9998 - val_loss: 8.3945e-04
# Epoch 48/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 0.9998 - val_loss: 8.4382e-04
# Epoch 49/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 0.9998 - val_loss: 8.4228e-04
# Epoch 50/50
# 1940/1940 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 0.9998 - val_loss: 8.4153e-04
# Training complete
# Loading NF-UNSW-NB15 testset 0
# (324624, 33)
# Loading complete
# Evaluating model trained on NF-ToN-IoT trainset on NF-UNSW-NB15 testset
# 10145/10145 ━━━━━━━━━━━━━━━━━━━━ 6s 614us/step
# Evaluation complete
# Results for:...
# Model trained on NF-ToN-IoT and evaluated on NF-UNSW-NB15
# [[115675 194537]
#  [  3643  10769]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.37      0.54    310212
#          1.0       0.05      0.75      0.10     14412
#
#     accuracy                           0.39    324624
#    macro avg       0.51      0.56      0.32    324624
# weighted avg       0.93      0.39      0.52    324624
#
# ---
# Loading NF-CSE-CIC-IDS2018 testset 1
# (1678480, 33)
# Loading complete
# Evaluating model trained on NF-ToN-IoT trainset on NF-CSE-CIC-IDS2018 testset
# 52453/52453 ━━━━━━━━━━━━━━━━━━━━ 31s 589us/step
# Evaluation complete
# Results for:...
# Model trained on NF-ToN-IoT and evaluated on NF-CSE-CIC-IDS2018
# [[517929 956610]
#  [153337  50604]]
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.35      0.48   1474539
#          1.0       0.05      0.25      0.08    203941
#
#     accuracy                           0.34   1678480
#    macro avg       0.41      0.30      0.28   1678480
# weighted avg       0.68      0.34      0.43   1678480
#
# ---
# Loading NF-BoT-IoT testset 2
# (120020, 33)
# Loading complete
# Evaluating model trained on NF-ToN-IoT trainset on NF-BoT-IoT testset
# 3751/3751 ━━━━━━━━━━━━━━━━━━━━ 2s 647us/step
# Evaluation complete
# Results for:...
# Model trained on NF-ToN-IoT and evaluated on NF-BoT-IoT
# [[  2439    339]
#  [117219     23]]
#               precision    recall  f1-score   support
#
#          0.0       0.02      0.88      0.04      2778
#          1.0       0.06      0.00      0.00    117242
#
#     accuracy                           0.02    120020
#    macro avg       0.04      0.44      0.02    120020
# weighted avg       0.06      0.02      0.00    120020
#
# ---
# Loading NF-ToN-IoT testset 3
# (275855, 33)
# Loading complete
# Evaluating model trained on NF-ToN-IoT trainset on NF-ToN-IoT testset
# 8621/8621 ━━━━━━━━━━━━━━━━━━━━ 6s 638us/step
# Evaluation complete
# Results for:...
# Model trained on NF-ToN-IoT and evaluated on NF-ToN-IoT
# [[ 53642     12]
#  [    64 222137]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     53654
#          1.0       1.00      1.00      1.00    222201
#
#     accuracy                           1.00    275855
#    macro avg       1.00      1.00      1.00    275855
# weighted avg       1.00      1.00      1.00    275855
#
# ---
# Loading X-IIoTiD testset 4
# (164018, 33)
# Loading complete
# Evaluating model trained on NF-ToN-IoT trainset on X-IIoTiD testset
# 5126/5126 ━━━━━━━━━━━━━━━━━━━━ 3s 579us/step
# Evaluation complete
# Results for:...
# Model trained on NF-ToN-IoT and evaluated on X-IIoTiD
# [[79954  4409]
#  [79441   214]]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.95      0.66     84363
#          1.0       0.05      0.00      0.01     79655
#
#     accuracy                           0.49    164018
#    macro avg       0.27      0.48      0.33    164018
# weighted avg       0.28      0.49      0.34    164018
#
# ---
# Loading WUSTL-IIOT testset 5
# (238165, 33)
# Loading complete
# Evaluating model trained on NF-ToN-IoT trainset on WUSTL-IIOT testset
# 7443/7443 ━━━━━━━━━━━━━━━━━━━━ 5s 603us/step
# Evaluation complete
# Results for:...
# Model trained on NF-ToN-IoT and evaluated on WUSTL-IIOT
# [[  1600 219315]
#  [ 11339   5911]]
#               precision    recall  f1-score   support
#
#          0.0       0.12      0.01      0.01    220915
#          1.0       0.03      0.34      0.05     17250
#
#     accuracy                           0.03    238165
#    macro avg       0.07      0.17      0.03    238165
# weighted avg       0.12      0.03      0.02    238165
#
# ---
# Cleanup complete
# ---+++---
# Loading X-IIoTiD trainingset
# (590463, 33)
# Loading complete
# Training on X-IIoTiD trainingset
# Epoch 1/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7910 - loss: 0.4518 - val_accuracy: 0.9259 - val_loss: 0.2139
# Epoch 2/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9334 - loss: 0.1957 - val_accuracy: 0.9493 - val_loss: 0.1339
# Epoch 3/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9501 - loss: 0.1274 - val_accuracy: 0.9563 - val_loss: 0.1051
# Epoch 4/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9588 - loss: 0.1033 - val_accuracy: 0.9619 - val_loss: 0.0945
# Epoch 5/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9621 - loss: 0.0905 - val_accuracy: 0.9637 - val_loss: 0.0841
# Epoch 6/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9638 - loss: 0.0814 - val_accuracy: 0.9652 - val_loss: 0.0746
# Epoch 7/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9664 - loss: 0.0733 - val_accuracy: 0.9837 - val_loss: 0.0704
# Epoch 8/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9708 - loss: 0.0659 - val_accuracy: 0.9851 - val_loss: 0.0605
# Epoch 9/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9760 - loss: 0.0591 - val_accuracy: 0.9861 - val_loss: 0.0529
# Epoch 10/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9807 - loss: 0.0529 - val_accuracy: 0.9867 - val_loss: 0.0479
# Epoch 11/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9833 - loss: 0.0487 - val_accuracy: 0.9871 - val_loss: 0.0445
# Epoch 12/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9850 - loss: 0.0443 - val_accuracy: 0.9876 - val_loss: 0.0425
# Epoch 13/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9861 - loss: 0.0413 - val_accuracy: 0.9878 - val_loss: 0.0429
# Epoch 14/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9870 - loss: 0.0386 - val_accuracy: 0.9886 - val_loss: 0.0391
# Epoch 15/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9872 - loss: 0.0372 - val_accuracy: 0.9892 - val_loss: 0.0360
# Epoch 16/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9875 - loss: 0.0359 - val_accuracy: 0.9901 - val_loss: 0.0351
# Epoch 17/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9887 - loss: 0.0332 - val_accuracy: 0.9907 - val_loss: 0.0346
# Epoch 18/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9868 - loss: 0.0386 - val_accuracy: 0.9912 - val_loss: 0.0301
# Epoch 19/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9902 - loss: 0.0301 - val_accuracy: 0.9914 - val_loss: 0.0286
# Epoch 20/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9908 - loss: 0.0287 - val_accuracy: 0.9923 - val_loss: 0.0272
# Epoch 21/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9916 - loss: 0.0274 - val_accuracy: 0.9935 - val_loss: 0.0283
# Epoch 22/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9877 - loss: 0.0523 - val_accuracy: 0.9941 - val_loss: 0.0248
# Epoch 23/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9930 - loss: 0.0254 - val_accuracy: 0.9949 - val_loss: 0.0244
# Epoch 24/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9930 - loss: 0.0251 - val_accuracy: 0.9915 - val_loss: 0.0251
# Epoch 25/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9934 - loss: 0.0234 - val_accuracy: 0.9964 - val_loss: 0.0212
# Epoch 26/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9942 - loss: 0.0225 - val_accuracy: 0.9966 - val_loss: 0.0212
# Epoch 27/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9946 - loss: 0.0220 - val_accuracy: 0.9926 - val_loss: 0.0229
# Epoch 28/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9944 - loss: 0.0209 - val_accuracy: 0.9971 - val_loss: 0.0188
# Epoch 29/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9955 - loss: 0.0195 - val_accuracy: 0.9968 - val_loss: 0.0187
# Epoch 30/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9951 - loss: 0.0234 - val_accuracy: 0.9972 - val_loss: 0.0177
# Epoch 31/50
# ...
# Epoch 42/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9970 - loss: 0.0129 - val_accuracy: 0.9972 - val_loss: 0.0143
# Epoch 43/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9971 - loss: 0.0124 - val_accuracy: 0.9970 - val_loss: 0.0199
# Epoch 44/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9942 - loss: 0.0248 - val_accuracy: 0.9973 - val_loss: 0.0119
# Epoch 45/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9972 - loss: 0.0114 - val_accuracy: 0.9972 - val_loss: 0.0142
# Epoch 46/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9972 - loss: 0.0113 - val_accuracy: 0.9972 - val_loss: 0.0128
# Epoch 47/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9966 - loss: 0.0167 - val_accuracy: 0.9972 - val_loss: 0.0124
# Epoch 48/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9971 - loss: 0.0114 - val_accuracy: 0.9972 - val_loss: 0.0115
# Epoch 49/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9971 - loss: 0.0110 - val_accuracy: 0.9972 - val_loss: 0.0128
# Epoch 50/50
# 1154/1154 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9972 - loss: 0.0106 - val_accuracy: 0.9974 - val_loss: 0.0110
# Training complete
# Loading NF-UNSW-NB15 testset 0
# (324624, 33)
# Loading complete
# Evaluating model trained on X-IIoTiD trainset on NF-UNSW-NB15 testset
# 10145/10145 ━━━━━━━━━━━━━━━━━━━━ 7s 664us/step
# Evaluation complete
# Results for:...
# Model trained on X-IIoTiD and evaluated on NF-UNSW-NB15
# [[213160  97052]
#  [     0  14412]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.69      0.81    310212
#          1.0       0.13      1.00      0.23     14412
#
#     accuracy                           0.70    324624
#    macro avg       0.56      0.84      0.52    324624
# weighted avg       0.96      0.70      0.79    324624
#
# ---
# Loading NF-CSE-CIC-IDS2018 testset 1
# (1678480, 33)
# Loading complete
# Evaluating model trained on X-IIoTiD trainset on NF-CSE-CIC-IDS2018 testset
# 52453/52453 ━━━━━━━━━━━━━━━━━━━━ 32s 612us/step
# Evaluation complete
# Results for:...
# Model trained on X-IIoTiD and evaluated on NF-CSE-CIC-IDS2018
# [[565086 909453]
#  [ 56046 147895]]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.38      0.54   1474539
#          1.0       0.14      0.73      0.23    203941
#
#     accuracy                           0.42   1678480
#    macro avg       0.52      0.55      0.39   1678480
# weighted avg       0.82      0.42      0.50   1678480
#
# ---
# Loading NF-BoT-IoT testset 2
# (120020, 33)
# Loading complete
# Evaluating model trained on X-IIoTiD trainset on NF-BoT-IoT testset
# 3751/3751 ━━━━━━━━━━━━━━━━━━━━ 3s 690us/step
# Evaluation complete
# Results for:...
# Model trained on X-IIoTiD and evaluated on NF-BoT-IoT
# [[    22   2756]
#  [     0 117242]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.01      0.02      2778
#          1.0       0.98      1.00      0.99    117242
#
#     accuracy                           0.98    120020
#    macro avg       0.99      0.50      0.50    120020
# weighted avg       0.98      0.98      0.97    120020
#
# ---
# Loading NF-ToN-IoT testset 3
# (275855, 33)
# Loading complete
# Evaluating model trained on X-IIoTiD trainset on NF-ToN-IoT testset
# 8621/8621 ━━━━━━━━━━━━━━━━━━━━ 5s 632us/step
# Evaluation complete
# Results for:...
# Model trained on X-IIoTiD and evaluated on NF-ToN-IoT
# [[ 15872  37782]
#  [ 22400 199801]]
#               precision    recall  f1-score   support
#
#          0.0       0.41      0.30      0.35     53654
#          1.0       0.84      0.90      0.87    222201
#
#     accuracy                           0.78    275855
#    macro avg       0.63      0.60      0.61    275855
# weighted avg       0.76      0.78      0.77    275855
#
# ---
# Loading X-IIoTiD testset 4
# (164018, 33)
# Loading complete
# Evaluating model trained on X-IIoTiD trainset on X-IIoTiD testset
# 5126/5126 ━━━━━━━━━━━━━━━━━━━━ 4s 690us/step
# Evaluation complete
# Results for:...
# Model trained on X-IIoTiD and evaluated on X-IIoTiD
# [[84276    87]
#  [  385 79270]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     84363
#          1.0       1.00      1.00      1.00     79655
#
#     accuracy                           1.00    164018
#    macro avg       1.00      1.00      1.00    164018
# weighted avg       1.00      1.00      1.00    164018
#
# ---
# Loading WUSTL-IIOT testset 5
# (238165, 33)
# Loading complete
# Evaluating model trained on X-IIoTiD trainset on WUSTL-IIOT testset
# 7443/7443 ━━━━━━━━━━━━━━━━━━━━ 5s 671us/step
# Evaluation complete
# Results for:...
# Model trained on X-IIoTiD and evaluated on WUSTL-IIOT
# [[220356    559]
#  [  1628  15622]]
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00    220915
#          1.0       0.97      0.91      0.93     17250
#
#     accuracy                           0.99    238165
#    macro avg       0.98      0.95      0.96    238165
# weighted avg       0.99      0.99      0.99    238165
#
# ---
# Cleanup complete
# ---+++---
# Loading WUSTL-IIOT trainingset
# (857390, 33)
# Loading complete
# Training on WUSTL-IIOT trainingset
# Epoch 1/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9738 - loss: 0.0929 - val_accuracy: 0.9994 - val_loss: 0.0034
# Epoch 2/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9996 - loss: 0.0024 - val_accuracy: 0.9998 - val_loss: 9.3586e-04
# Epoch 3/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9998 - loss: 0.0010 - val_accuracy: 0.9998 - val_loss: 6.0491e-04
# Epoch 4/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9998 - loss: 7.2145e-04 - val_accuracy: 0.9999 - val_loss: 4.3440e-04
# Epoch 5/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9999 - loss: 5.1645e-04 - val_accuracy: 0.9999 - val_loss: 3.7797e-04
# Epoch 6/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9999 - loss: 4.2192e-04 - val_accuracy: 0.9999 - val_loss: 3.2474e-04
# Epoch 7/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9999 - loss: 3.5293e-04 - val_accuracy: 0.9999 - val_loss: 2.7267e-04
# Epoch 8/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9999 - loss: 3.0623e-04 - val_accuracy: 0.9999 - val_loss: 2.3876e-04
# Epoch 9/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9999 - loss: 2.5704e-04 - val_accuracy: 0.9999 - val_loss: 1.6161e-04
# Epoch 10/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9999 - loss: 2.9282e-04 - val_accuracy: 1.0000 - val_loss: 7.0234e-05
# Epoch 11/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 1.0000 - loss: 1.0423e-04 - val_accuracy: 1.0000 - val_loss: 5.6642e-05
# Epoch 12/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 1.0000 - loss: 8.3069e-05 - val_accuracy: 1.0000 - val_loss: 5.2587e-05
# Epoch 13/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 1.0527e-04 - val_accuracy: 1.0000 - val_loss: 5.6526e-05
# Epoch 14/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 8.8779e-05 - val_accuracy: 1.0000 - val_loss: 4.6500e-05
# Epoch 15/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 7.4216e-05 - val_accuracy: 1.0000 - val_loss: 4.9276e-05
# Epoch 16/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 7.5109e-05 - val_accuracy: 1.0000 - val_loss: 5.1653e-05
# Epoch 17/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 1.0000 - loss: 7.4932e-05 - val_accuracy: 1.0000 - val_loss: 5.0894e-05
# Epoch 18/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 7.9339e-05 - val_accuracy: 1.0000 - val_loss: 5.0564e-05
# Epoch 19/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 7.4662e-05 - val_accuracy: 1.0000 - val_loss: 4.7390e-05
# Epoch 20/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 7.3991e-05 - val_accuracy: 1.0000 - val_loss: 4.7802e-05
# Epoch 21/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9999 - loss: 4.2269e-04 - val_accuracy: 1.0000 - val_loss: 3.7715e-05
# Epoch 22/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 7.1389e-05 - val_accuracy: 1.0000 - val_loss: 4.0819e-05
# Epoch 23/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 7.2809e-05 - val_accuracy: 1.0000 - val_loss: 4.9069e-05
# Epoch 24/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 1.0000 - loss: 7.3422e-05 - val_accuracy: 1.0000 - val_loss: 4.1216e-05
# Epoch 25/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 7.3979e-05 - val_accuracy: 1.0000 - val_loss: 5.0136e-05
# Epoch 26/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 9.0470e-05 - val_accuracy: 1.0000 - val_loss: 4.5599e-05
# Epoch 27/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 7.6291e-05 - val_accuracy: 1.0000 - val_loss: 4.1182e-05
# Epoch 28/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 1.0000 - loss: 7.2090e-05 - val_accuracy: 1.0000 - val_loss: 4.3897e-05
# Epoch 29/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 8.9706e-05 - val_accuracy: 1.0000 - val_loss: 4.1627e-05
# Epoch 30/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 7.4495e-05 - val_accuracy: 1.0000 - val_loss: 3.6745e-05
# Epoch 31/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 7.1695e-05 - val_accuracy: 1.0000 - val_loss: 3.5126e-05
# Epoch 32/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 8.1027e-05 - val_accuracy: 1.0000 - val_loss: 5.0330e-05
# Epoch 33/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 7.4663e-05 - val_accuracy: 1.0000 - val_loss: 3.9840e-05
# Epoch 34/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 7.2145e-05 - val_accuracy: 1.0000 - val_loss: 3.5477e-05
# Epoch 35/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 1.0000 - loss: 7.1523e-05 - val_accuracy: 1.0000 - val_loss: 2.6338e-05
# Epoch 36/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 1.0000 - loss: 7.9992e-05 - val_accuracy: 1.0000 - val_loss: 3.0767e-05
# Epoch 37/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 6.9594e-05 - val_accuracy: 1.0000 - val_loss: 2.4680e-05
# Epoch 38/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 6.9357e-05 - val_accuracy: 1.0000 - val_loss: 2.9131e-05
# Epoch 39/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 7.8590e-05 - val_accuracy: 1.0000 - val_loss: 2.1707e-05
# Epoch 40/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 1.0000 - loss: 6.4006e-05 - val_accuracy: 1.0000 - val_loss: 1.8684e-05
# Epoch 41/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 6.3062e-05 - val_accuracy: 1.0000 - val_loss: 1.8820e-05
# Epoch 42/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 6.0928e-05 - val_accuracy: 1.0000 - val_loss: 2.6512e-05
# Epoch 43/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 1.0000 - loss: 6.2752e-05 - val_accuracy: 1.0000 - val_loss: 1.1662e-05
# Epoch 44/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 5.7236e-05 - val_accuracy: 1.0000 - val_loss: 2.1449e-05
# Epoch 45/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 6.5166e-05 - val_accuracy: 1.0000 - val_loss: 7.1854e-06
# Epoch 46/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 3.4209e-05 - val_accuracy: 1.0000 - val_loss: 5.5700e-06
# Epoch 47/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 3.2936e-05 - val_accuracy: 1.0000 - val_loss: 7.2506e-05
# Epoch 48/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 1.0000 - loss: 2.7765e-05 - val_accuracy: 1.0000 - val_loss: 4.0489e-06
# Epoch 49/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 1.0000 - loss: 2.2997e-05 - val_accuracy: 1.0000 - val_loss: 4.0613e-06
# Epoch 50/50
# 1675/1675 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 2.7185e-05 - val_accuracy: 1.0000 - val_loss: 5.8702e-06
# Training complete
# Loading NF-UNSW-NB15 testset 0
# (324624, 33)
# Loading complete
# Evaluating model trained on WUSTL-IIOT trainset on NF-UNSW-NB15 testset
# 10145/10145 ━━━━━━━━━━━━━━━━━━━━ 6s 592us/step
# Evaluation complete
# Results for:...
# Model trained on WUSTL-IIOT and evaluated on NF-UNSW-NB15
# [[ 46687 263525]
#  [  2391  12021]]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.15      0.26    310212
#          1.0       0.04      0.83      0.08     14412
#
#     accuracy                           0.18    324624
#    macro avg       0.50      0.49      0.17    324624
# weighted avg       0.91      0.18      0.25    324624
#
# ---
# Loading NF-CSE-CIC-IDS2018 testset 1
# (1678480, 33)
# Loading complete
# Evaluating model trained on WUSTL-IIOT trainset on NF-CSE-CIC-IDS2018 testset
# 52453/52453 ━━━━━━━━━━━━━━━━━━━━ 30s 578us/step
# Evaluation complete
# Results for:...
# Model trained on WUSTL-IIOT and evaluated on NF-CSE-CIC-IDS2018
# [[ 461210 1013329]
#  [   1528  202413]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.31      0.48   1474539
#          1.0       0.17      0.99      0.29    203941
#
#     accuracy                           0.40   1678480
#    macro avg       0.58      0.65      0.38   1678480
# weighted avg       0.90      0.40      0.45   1678480
#
# ---
# Loading NF-BoT-IoT testset 2
# (120020, 33)
# Loading complete
# Evaluating model trained on WUSTL-IIOT trainset on NF-BoT-IoT testset
# 3751/3751 ━━━━━━━━━━━━━━━━━━━━ 2s 582us/step
# Evaluation complete
# Results for:...
# Model trained on WUSTL-IIOT and evaluated on NF-BoT-IoT
# [[   239   2539]
#  [   948 116294]]
#               precision    recall  f1-score   support
#
#          0.0       0.20      0.09      0.12      2778
#          1.0       0.98      0.99      0.99    117242
#
#     accuracy                           0.97    120020
#    macro avg       0.59      0.54      0.55    120020
# weighted avg       0.96      0.97      0.97    120020
#
# ---
# Loading NF-ToN-IoT testset 3
# (275855, 33)
# Loading complete
# Evaluating model trained on WUSTL-IIOT trainset on NF-ToN-IoT testset
# 8621/8621 ━━━━━━━━━━━━━━━━━━━━ 6s 738us/step
# Evaluation complete
# Results for:...
# Model trained on WUSTL-IIOT and evaluated on NF-ToN-IoT
# [[ 19591  34063]
#  [209802  12399]]
#               precision    recall  f1-score   support
#
#          0.0       0.09      0.37      0.14     53654
#          1.0       0.27      0.06      0.09    222201
#
#     accuracy                           0.12    275855
#    macro avg       0.18      0.21      0.12    275855
# weighted avg       0.23      0.12      0.10    275855
#
# ---
# Loading X-IIoTiD testset 4
# (164018, 33)
# Loading complete
# Evaluating model trained on WUSTL-IIOT trainset on X-IIoTiD testset
# 5126/5126 ━━━━━━━━━━━━━━━━━━━━ 4s 684us/step
# Evaluation complete
# Results for:...
# Model trained on WUSTL-IIOT and evaluated on X-IIoTiD
# [[65772 18591]
#  [73750  5905]]
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.78      0.59     84363
#          1.0       0.24      0.07      0.11     79655
#
#     accuracy                           0.44    164018
#    macro avg       0.36      0.43      0.35    164018
# weighted avg       0.36      0.44      0.36    164018
#
# ---
# Loading WUSTL-IIOT testset 5
# (238165, 33)
# Loading complete
# Evaluating model trained on WUSTL-IIOT trainset on WUSTL-IIOT testset
# 7443/7443 ━━━━━━━━━━━━━━━━━━━━ 5s 636us/step
# Evaluation complete
# Results for:...
# Model trained on WUSTL-IIOT and evaluated on WUSTL-IIOT
# [[220915      0]
#  [     0  17250]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00    220915
#          1.0       1.00      1.00      1.00     17250
#
#     accuracy                           1.00    238165
#    macro avg       1.00      1.00      1.00    238165
# weighted avg       1.00      1.00      1.00    238165
#
# ---
# Cleanup complete
# ---+++---
# CPU times: user 1h 43min 38s, sys: 9min 16s, total: 1h 52min 55s
# Wall time: 53min 18s

# %%
result_df.to_csv(cwd+"/results/"+model_name+"_results.csv",index=False)
